# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report section Title & Abstract trhough Data Wrangling:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#
# For the report section Data Visualizations through Documentation and Written Communication:
# - Each Developing  => -1 pts
# - Each Unsatisfactory/Missing => -2 pts
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# Until the score is 0
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Ethics                                                                             | No effort or just says we have no ethical concerns                                                                                                                                                                                                                                                  | Minimal ethical section; probably just talks about data privacy and no unintended consequences discussion. Ethical concerns raised seem irrelevant.                                                                                                                                                 | The ethical concerns described are appropriate and sufficiently                                                                                                                                                                                                                                                                     | Ethical concerns are described clearly and succinctly. This was clearly a thorough and nuanced approach to the issues                                                                                                                                                                                                          |
# | Data visualizations                                                                | No plots. Or most plots don't capture useful information, or their display of information is difficult to understand. Legends, labels, axes, titles, captions, etc of most plots may be poor or missing. Most figures are not referenced in the main text.                                          | Fewer than 3 relevant plots (irrelevant to the question plots do not count).  Or a few of the plots don't make sense or capture useful information. Legends, labels, axes, titles, captions, etc are illegible or inadequately describe the content in a few figures. Or a few figures are not referenced or explained inside the main text. | Plots almost all make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | No analyses beyond EDA style explorations of the dataset. Or analyses presented do not help address the question/hypothesis. Or most of the analyses presented are not technically approriate (eg. using parametric methods for non-parametric data).                                              | Only one analysis beyond EDA. Or a few analyses presented do not address the question/hypothesis. Or a few of the analyses presented are not technically approriate                                                                                                                                                                  |  At least two analyses beyond EDA. That is, the project uses two different techniques (e.g., inference vs machine learning; or t-test vs regression; or entire dataset vs stratified) or two different proxies for the same concept are investigated.  Each analysis addressed the question/hypothesis and is technically approriate. | Many different analyses are used. Each analysis addressed an aspect of the question/hypothesis and is technically approriate. Perhaps they use multiple datasets, or do something else to go the extra mile and address the reliability of the results                                            |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Please write one to four paragraphs that describe a very brief overview of why you did this, how you did, and the major findings and conclusions.
#
#        This project was ran to investigate whether or not there was a positive correlation between air pollution and length of poweroutages. We wanted to see which ones correlate the most and in which region, which could be helpful for people in those regions to anticipate the outages. To do this, we investigated trends in two datasets to find correlations between the outage lengths and the pollutants. We also checked for separate regions and utilized K-Nearest Neighbors to see where the correlations were most informative.
#        We found that year was a major confounder in the data, and used it as a covariate appropriately. We found that severe weather was the most common cause of power outages and also displayed the highest correlation between air pollution and outage length. The correlation varied significantly by region as well. With all of these accounted for, we found air pollution and power outage length do weakly correlate, but air pollution may likely be a proxy for other underlying conditions, and may not be a great predictor of power outage length in itself.

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# - Manning Karahashi: Analysis, Experimental investigation
# - Emily Nguyen: Project administration, Writing - original draft, Writing - review and editing
# - Christian Paddie: Background research, Conceptualization
# - Lucas Vocelka: Data curation, Experimental investigation
# - Andrew Gooboian: Methodology, Software, Visualization

# %% [markdown]
# ## Research Question

# %% [markdown]
# Is a rise in air pollutants accompanied by an increase in the severity (length/cost) of a power outage in the continental United States of America, and do these predictors change by region?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
#  In the United States, air quality is monitored and defined by the Environmental Protection Agency (EPA) responsible for the protection of human health as well as environment. Air quality is characterized as the concentration of specific pollutants in the atmosphere and their resulting effects on the health of the public/environment. The EPA’s Air Quality Index (AQI) ranges from “Good” to “Hazardous” where the severity of pollutant diffusion across the atmosphere poses little risk to the public (“Good”) to everyone being increasingly likely to experience adverse effects from its exposure (“Hazardous”). The AQI’s index values intuitively rate air quality by having a higher AQI value meaning the greater the level of air pollution and vice versa.1 It is important to note however that the AQI is a composite measure and takes multiple air pollutants into account rather than just an individual pollutant concentration.
#
#   As the relationship between power outages and air pollution is concerned, previous work has been done in Ecuador, specifically in the capital, Quito, and their 2023 and 2024 power outages which saw large scale blackouts for several hours for consecutive months. Researchers Vallejo and their colleagues posit that Quito’s blackouts, “...revealed a significant deterioration in atmospheric pollution, primarily driven by the widespread use of diesel generators, increased vehicular traffic, and adverse meteorological conditions…”2 Vallejo and colleagues’ work in the context of Ecuador’s 2023 and 2024 power outages reveals an interesting interaction between infrastructural issues such as blackouts and the increased usage of alternative power sources which produce pollutants and deteriorate the atmosphere. Another work that explores the relationship between air pollution and power outages takes a similar look at how Delhi, India and its citizens grapple with power outages through reliance on backup solutions like diesel generators. Yatang Lin and Dana Kassem note that diesel generators “...emit 3.5 times more nitrogen oxides and two times more particulate matter than coal-fired plants for the same amount of energy,” which is worsened by the fact that Delhi’s power outages are locally combatted through “The frequent on-off cycling of backup generators…” which “...further increases fuel consumption and pollution,”3 Lin and Kassem’s findings further display the downstream pollutive effects of power outages and how they influence worsening air quality. This explains a possible reasoning as to why air pollutants and strength of power outage could be correlated. This correlation found in this work is the type of relationships we wish find with our research question. To be subject to frequent blackouts and power outages coupled with a reliance on alternative power sources which negatively impact air quality establishes this relationship wherein power outages can possibly predict worsening air quality/pollution.
#
#   An important consideration when discussing air quality involves the health complications that come with exposure to air pollutants. As detailed by California’s Air Resources Board, the reliance on backup generators (which are primarily diesel generators) and their emission of diesel particulate matter (DPM) is considered a toxic air contaminant implicated in the development of cancer and increasing the lung’s susceptibility to damage.4 The ability for air pollution and power outages to influence one another has an impact on health either way through exposure to harmful airborne substances or as how Zhang and colleagues put it, power outages threaten vulnerable populations as they suggest an increased risk of COPD exacerbation, as a result of their dependency on electricity.5 The importance of air quality and power reliability and its influences on the health of the public cannot be understated. The relationship established in the Quito and Delhi examples (failing power infrastructure predicting worsening air quality) can be explored in the United States as well, a particular pathway of interest to prevent this type of event is the initiation of public safety power shutoffs (PSPS) performed in California to proactively prevent wildfires by electrical infrastructure. Huang and colleagues frame PSPS "As one of the most critical wildfire mitigation strategies, PSPS, present a strong interaction between wildfires, electric infrastructure, and customers,"6 Huang and colleagues' in examining California's unique interaction with its dry climate which exacerbate the catastrophic nature of wildfires sparked through electrical infrastructure failures, establishes that outage severity is correlated with an electrical system's potential for harm environmentally through wildfires which are extensively documented to negatively impact air quality. Not to mention dry heat and windy weather conditions, which are commonly experienced in California, independently and simultaneously impact air quality in tandem with increasing the risk of a PSPS to prevent wildfires by virtue of failing electrical equipment.
#
#   We are already made well aware that power outages/failing electrical infrastructure can influence air quality (evidenced above), but we wish to examine if air pollution is able to have a statistically significant correlation with power outage severity, the temporality of the two issues essentially being swapped with what was observed in the background research. Prior work has established that outages cause pollution (A→B); we are testing whether pollution predicts outage severity (B→A). This project examines the relationship between air pollution and power outages within the context of the United States and intends to explore the inverse of the previously established case studies done in Quito and Delhi. We intend to examine if air pollutants are a predictor for the severity (length/cost) of power outages nationally, and if these predictors (specific air pollutants) are subject to variability per US region. This project intends on leaning into the fact that air quality predicting power outage events or at least having a correlation to an outage's severity is seldom researched. The previously established relationships are very intuitive and easy to think about as having electricity is a necessity in this day and age, thus it is nigh unto instinctual that people search for alternatives to maintain the luxuries and the way of life brought about through electricity through alternative power sources regardless of its harms on air quality or its capacity for pollution. Possible avenues can be explored in examing the correlation we wish to establish between air pollution and power outage severity. For instance, is it possible that the widely accepted and proven relationship that air pollution has on the degradation on the climate of an area may affect electrical infrastructure and cause fires which resultantly influence air quality, or damaged/heavily polluted climates may require more energy usage to make living tolerable which puts stress on these areas' power grids. These are very interesting potential explanations for the relationship we want to examine, but of course none of these can be causally established with the tools we decided to implement, they just provide us with possible areas of observation/interest. Limiting the scope to the United States was decided on account of the fact that the entire continental US has a diverse array of natural environments, varying degrees of urban sprawl and suburban areas, and with regions with their own power grids, thus we are sourcing from data that would be more robust than collecting by county and more focussed than collecting by continent.
#
#   The data sources we use reflect these two sides of the relationship directly. The CACES dataset operationalizes ambient air quality through the same six criteria pollutants — CO, NO₂, O₃, PM10, PM2.5, and SO₂ — that compose the EPA's AQI described above, providing annual population-weighted concentration estimates at the county level across the full study period.7 The Purdue Major Power Outage dataset operationalizes outage severity through duration, customers affected, and demand loss and includes cause category and climate region classifications that allow us to test whether any association is specific to weather-caused events (the subset where shared atmospheric drivers are most plausible) and whether it varies across the nine U.S. climate zones documented by Mukherjee and colleagues.8 Neither dataset alone can address our research question, the contribution of this analysis is specifically in the merger of the two, linking ambient pollution levels to outage outcomes in the same state and year, and examining whether that linkage is consistent or region-dependent. It is worth noting that weather operates as a likely confounder throughout this analysis — atmospheric conditions independently influence both air quality and power outage risk in ways that are difficult to fully separate. Our subgroup analysis of weather-caused outages helps isolate the events where this overlap is most direct.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that air pollutant concentrations will show a positive correlation with power outage severity, measured primarily by outage duration, and that the strength of this association will vary meaningfully by climate region. The causation between air quality and power infrastructure tends to run from outages worsening pollution rather than the other way. This prediction is grounded in the idea that severe weather dominates outage causes, particularly in the midwest/southern parts of the US, and on the assumption that air pollutants are a general indicator of climate change as a whole, which is linked to severe weather events.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# Our research question has two distinct components: (1) whether air pollutant levels predict power outage severity, and (2) whether these predictors vary by region. Answering it requires one dataset that measures ambient air pollution across U.S. states over time, and a separate dataset that records the severity, cause, and geographic location of power outage events over the same period. The CACES data has no outage information, and the Purdue data has no air quality measurements, so both are strictly necessary for this analysis. The analysis depends on merging them into a single state × year dataset where both pollution levels and outage metrics are jointly observed.
#
# CACES U.S. Air Quality Data (https://www.caces.us/data) provides the air pollution side of the analysis. It supplies annual, county-level, population-weighted ambient concentration estimates forten pollutants — CO, NO₂, O₃, BC, PM10, PM2.5, SO₂, COA, HOA, and PNC — covering 1979–2020. Key columns are fips (county identifier), pollutant, year, pred_wght (the population-weighted concentration estimate), state_abbr, lat, and lon. Estimates are derived from EPA monitoring networks combined with land-use regression models, providing coverage even for counties without physical monitoring stations. Population-weighting means the estimate reflects the exposure experienced by an average resident of that county rather than a simple geographic average, making it more meaningful for health and policy analysis than a raw spatial mean.
#
# Because the outage dataset records location only at the state level, we aggregate CACES county estimates to annual state means using state_abbr and year as keys. This loses within-state spatial variation but produces a common geographic identifier for merging. Four of the ten pollutants (BC, COA, HOA, PNC) have sparse coverage that does not overlap with the outage dataset's 2000–2016 window after merging, and are excluded from modeling — leaving CO, NO₂, O₃, PM10, PM2.5, and SO₂ as the six predictors used in analysis. These six are also the primary components of the EPA's AQI described in the background, making them the most policy-relevant measures available.
#
# Purdue Major Power Outage Risks in the U.S. (https://engineering.purdue.edu/LASCI/research-data/outages) provides the outage severity side of the analysis. It records 1,534 major power outage events in the contiguous U.S. from January 2000 to July 2016, with one row per event. The variables we use as outage severity outcomes are OUTAGE.DURATION (minutes) and CUSTOMERS.AFFECTED — directly measuring how long and how widely each outage impacted the grid. DEMAND.LOSS.MW provides a third severity measure reflecting peak grid stress. CAUSE.CATEGORY is critical for our analysis because severe weather is the only cause with a plausible atmospheric connection to air quality — we use it to subset analyses and test whether the pollutant-outage association is stronger in weather-caused events specifically. CLIMATE.REGION (nine U.S. climate zones) is the primary variable for the regional heterogeneity component of our question, allowing us to test whether pollutant-outage associations differ across climate zones. Sector-level electricity prices (RES.PRICE, COM.PRICE, IND.PRICE, TOTAL.PRICE) serve as economic control variables rather than outcomes, since they reflect state energy market conditions rather than outage-specific severity.
#
# Because outage events are recorded individually but CACES is annual and state-level, we aggregate outage events to state × year means and counts before merging. The two datasets are joined on state_abbr and year using an inner join, retaining only state-years present in restricting the analysis to 2000–2016 across the contiguous 48 states. The merged dataset is the sole input to all EDA and modeling: CACES contributes the six pollutant concentration columns, and the Purdue data contributes the outage severity metrics, cause breakdown, and climate region classification.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import
from eda_utils import partial_r_year
import get_data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://docs.google.com/spreadsheets/d/1eP7XIrHZv4AiFUk-YISoRdKlYedUAstW/export?format=xlsx', 'filename':'power_outage_data.xlsx'},
    { 'url': 'https://docs.google.com/spreadsheets/d/1mNQ2BhRzK5MApRL1XiINT4zxwkdDp79m/export?format=xlsx', 'filename':'caces_us_data.xlsx'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# ...
# Overall Download Progress:  50%|█████     | 1/2 [00:00<00:00,  1.03it/s]
# Successfully downloaded: power_outage_data.xlsx
# ...
# Overall Download Progress: 100%|██████████| 2/2 [00:19<00:00,  9.85s/it]
# Successfully downloaded: caces_us_data.xlsx

# %% [markdown]
# ### Dataset #1 (use name instead of number here)
#
# **NOTE** The final report should not be overly long.  If this wrangling step is huge and complicated you should remove these sections from the final report and replace them with a statement like "To see the code responsible for wrangling the data see `01-DataCheckpoint.ipynb`. From here on we will simply load the processed data for further analysis"

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION 
import pandas as pd
import os

caces_raw = pd.read_excel('data/00-raw/caces_us_data.xlsx')

print("raw shape")
print(caces_raw.shape)
print("\ncolumns")
print(caces_raw.columns.tolist())
print("\nheader")
caces_raw.head()
# Out:
# raw shape
# (668386, 7)
#
# columns
# ['fips', 'pollutant', 'year', 'pred_wght', 'state_abbr', 'lat', 'lon']
#
# header
#     fips pollutant  year  pred_wght state_abbr        lat         lon
# 0  48241        co  2004   0.260467         TX  30.736463  -93.994112
# 1  48243        co  2004   0.380306         TX  30.603581 -103.990326
# 2  48245        co  2004   0.352974         TX  30.012330  -94.067619
# 3  48247        co  2004   0.280159         TX  27.304606  -98.683616
# 4  48249        co  2004   0.324230         TX  27.751907  -98.064534

# %%
# Tidy check
print("One row per (fips, year, pollutant)?")
dupes = caces_raw.duplicated(subset=['fips','year','pollutant']).sum()
print(f"Duplicate (fips, year, pollutant) rows: {dupes}")

print(f"\nPollutants present: {sorted(caces_raw['pollutant'].unique())}")
print(f"Year range: {caces_raw['year'].min()} – {caces_raw['year'].max()}")
print(f"Unique states: {caces_raw['state_abbr'].nunique()}")
print(f"Unique counties (FIPS): {caces_raw['fips'].nunique()}")
# Out:
# One row per (fips, year, pollutant)?
# Duplicate (fips, year, pollutant) rows: 0
#
# Pollutants present: ['bc', 'co', 'coa', 'hoa', 'no2', 'o3', 'pm10', 'pm25', 'pnc', 'so2']
# Year range: 1979 – 2020
# Unique states: 49
# Unique counties (FIPS): 3109

# %%
# Missing data 
print("missing values")
miss = caces_raw.isnull().sum()
miss_pct = (miss / len(caces_raw) * 100).round(2)
missing_df = pd.DataFrame({'missing_count': miss, 'missing_pct': miss_pct})
print(missing_df[missing_df['missing_count'] > 0])

# Check if missingness is systematic by pollutant
print("\nmissing pred_wght by pollutant")
print(
    caces_raw[caces_raw['pred_wght'].isna()]
    .groupby('pollutant')
    .size()
    .rename('missing_count')
)
# Out:
# missing values
# Empty DataFrame
# Columns: [missing_count, missing_pct]
# Index: []
#
# missing pred_wght by pollutant
# Series([], Name: missing_count, dtype: int64)

# %%
# Outlier check on pred_wght 
print("pred_wght summary stats by pollutant")
print(
    caces_raw.groupby('pollutant')['pred_wght']
    .describe()
    .round(4)
    .to_string()
)

# Flag extreme outliers (> 5 IQR from median) per pollutant
def flag_outliers(group):
    q1, q3 = group['pred_wght'].quantile([0.25, 0.75])
    iqr = q3 - q1
    return group[
        (group['pred_wght'] < q1 - 5 * iqr) |
        (group['pred_wght'] > q3 + 5 * iqr)
    ]

outliers = caces_raw.groupby('pollutant', group_keys=False).apply(flag_outliers)
print(f"\nExtreme outliers (>5 IQR): {len(outliers)} rows")
print(outliers[['fips','state_abbr','year','pollutant','pred_wght']]
      .sort_values('pred_wght', ascending=False).head(10))
# Out:
# pred_wght summary stats by pollutant
#               count       mean        std        min        25%        50%        75%         max
# pollutant
# bc           3104.0     0.3126     0.0909     0.2128     0.2553     0.2849     0.3354      0.9073
# co          96374.0     0.3161     0.1308     0.0051     0.2260     0.2956     0.3744      1.9039
# coa          3104.0     0.2127     0.1184     0.0715     0.1318     0.1812     0.2587      1.2735
# hoa          3104.0     0.1131     0.0811     0.0033     0.0549     0.0945     0.1524      0.7319
# no2        130573.0     7.3667     4.8574     0.0275     4.2525     6.3760     9.0654     77.0764
# o3         127465.0    48.6184     7.4029    16.1451    43.4578    48.3986    53.4010    847.5134
# pm10       102592.0    19.1626     5.2903     3.4823    15.4983    19.1166    22.4630     65.5180
# pm25        68393.0     8.7705     2.7290     1.8231     6.7849     8.3184    10.5487     22.1217
# ...

# %%
# Clean & aggregate to state × year 
caces = caces_raw.copy()
caces.columns = caces.columns.str.strip().str.lower()

# Restrict to the 6 well-covered pollutants
POLLUTANTS = ["co", "no2", "o3", "pm10", "pm25", "so2"]
caces_filtered = caces[caces['pollutant'].str.lower().isin(POLLUTANTS)].copy()
caces_filtered['pollutant'] = caces_filtered['pollutant'].str.lower()

# Aggregate to state × year: population-weighted mean across counties
state_yr_long = (
    caces_filtered
    .groupby(['year', 'state_abbr', 'pollutant'])['pred_wght']
    .mean()
    .reset_index()
)

state_yr = (
    state_yr_long
    .pivot_table(index=['year','state_abbr'], columns='pollutant', values='pred_wght')
    .reset_index()
)
state_yr.columns.name = None
state_yr = state_yr.rename(columns={p: f'poll_{p}' for p in POLLUTANTS})

# Normalise keys
state_yr['state_abbr'] = state_yr['state_abbr'].str.strip().str.upper()
state_yr['year'] = state_yr['year'].astype(int)

print("processed caces shape")
print(state_yr.shape)
print(f"\nYears: {state_yr['year'].min()} – {state_yr['year'].max()}")
print(f"States: {state_yr['state_abbr'].nunique()}")
print("\nheaderS")
state_yr.head()
# Out:
# processed caces shape
# (2058, 8)
#
# Years: 1979 – 2020
# States: 49
#
# headerS
#    year state_abbr  poll_co   poll_no2    poll_o3  poll_pm10  poll_pm25  \
# 0  1979         AL      NaN  31.294478  73.918510        NaN        NaN
# 1  1979         AR      NaN  20.445871  66.348316        NaN        NaN
# 2  1979         AZ      NaN  14.362425  60.242537        NaN        NaN
# 3  1979         CA      NaN  20.441788  57.183033        NaN        NaN
# 4  1979         CO      NaN  15.801318  57.554843        NaN        NaN
#
#     poll_so2
# 0   8.509880
# 1   7.898970
# 2  19.388903
# 3   3.448873
# 4   5.111314

# %%
# Write to processed 
os.makedirs('data/02-processed', exist_ok=True)
state_yr.to_excel('data/02-processed/caces_state_year.xlsx', index=False)
print("Saved: data/02-processed/caces_state_year.xlsx")
# Out:
# Saved: data/02-processed/caces_state_year.xlsx

# %% [markdown]
# ### Dataset #2 (if you have more than one, use name instead of number here)

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION 
# The Purdue Excel file has metadata rows above the header; skiprows=5
raw = pd.read_excel(
    'data/00-raw/power_outage_data.xlsx',
    sheet_name=0,
    skiprows=5,
    header=0
)
raw.columns = raw.columns.str.strip()

print("raw shape")
print(raw.shape)
print("\nFfirst 3 rows, first 8 columns")
print(raw.iloc[:3, :8].to_string())
print("\nall columns")
print(raw.columns.tolist())
# Out:
# raw shape
# (1535, 57)
#
# Ffirst 3 rows, first 8 columns
#   variables  OBS    YEAR  MONTH U.S._STATE POSTAL.CODE NERC.REGION      CLIMATE.REGION
# 0     Units  NaN     NaN    NaN        NaN         NaN         NaN                 NaN
# 1       NaN  1.0  2011.0    7.0  Minnesota          MN         MRO  East North Central
# 2       NaN  2.0  2014.0    5.0  Minnesota          MN         MRO  East North Central
#
# all columns
# ...

# %%
# Tidy check & header fix
outage = raw.copy()
outage = outage[pd.to_numeric(outage['YEAR'], errors='coerce').notna()].copy()

print(f"Rows after removing non-data rows: {len(outage)}")

dupes = outage.duplicated().sum()
print(f"Fully duplicate rows: {dupes}")
# Out:
# Rows after removing non-data rows: 1534
# Fully duplicate rows: 0

# %%
# Rename columns
col_map = {
    'YEAR'                    : 'year',
    'MONTH'                   : 'month',
    'U.S._STATE'              : 'state',
    'POSTAL.CODE'             : 'state_abbr',
    'NERC.REGION'             : 'nerc_region',
    'CLIMATE.REGION'          : 'climate_region',
    'CLIMATE.CATEGORY'        : 'climate_category',
    'ANOMALY.LEVEL'           : 'anomaly_level',
    'CAUSE.CATEGORY'          : 'cause_category',
    'CAUSE.CATEGORY.DETAIL'   : 'cause_detail',
    'OUTAGE.DURATION'         : 'outage_duration_min',
    'DEMAND.LOSS.MW'          : 'demand_loss_mw',
    'CUSTOMERS.AFFECTED'      : 'customers_affected',
    'RES.PRICE'               : 'price_residential',
    'COM.PRICE'               : 'price_commercial',
    'IND.PRICE'               : 'price_industrial',
    'TOTAL.PRICE'             : 'price_total',
    'TOTAL.SALES'             : 'total_sales_mwh',
    'TOTAL.CUSTOMERS'         : 'total_customers',
    'PC.REALGSP.STATE'        : 'real_gsp_usd',
    'PC.REALGSP.CHANGE'       : 'real_gsp_change',
    'POPULATION'              : 'population',
    'POPPCT_URBAN'            : 'pct_urban_pop',
    'POPDEN_URBAN'            : 'pop_density_urban',
    'OUTAGE.START.DATE'       : 'outage_start_date',
    'OUTAGE.RESTORATION.DATE' : 'outage_restore_date',
}
col_map = {k: v for k, v in col_map.items() if k in outage.columns}
outage = outage.rename(columns=col_map)

# Numeric coercion 
num_cols = [
    'year', 'month', 'outage_duration_min', 'customers_affected',
    'demand_loss_mw', 'price_residential', 'price_commercial',
    'price_industrial', 'price_total', 'total_sales_mwh',
    'total_customers', 'real_gsp_usd', 'population', 'pop_density_urban',
]
for c in num_cols:
    if c in outage.columns:
        outage[c] = pd.to_numeric(outage[c], errors='coerce')

outage = outage.dropna(subset=['state', 'year'])
outage['year'] = outage['year'].astype(int)
outage['state_abbr'] = outage['state_abbr'].str.strip().str.upper()
outage['outage_duration_hr'] = outage['outage_duration_min'] / 60

print("")
print(outage.shape)
print(f"\nYears: {outage['year'].min()} – {outage['year'].max()}")
print(f"States: {outage['state_abbr'].nunique()}")
outage[['year','state','state_abbr','cause_category',
        'outage_duration_min','price_total']].head()
# Out:
# (1534, 58)
#
# Years: 2000 – 2016
# States: 50
#    year      state state_abbr      cause_category  outage_duration_min  \
# 1  2011  Minnesota         MN      severe weather               3060.0
# 2  2014  Minnesota         MN  intentional attack                  1.0
# 3  2010  Minnesota         MN      severe weather               3000.0
# 4  2012  Minnesota         MN      severe weather               2550.0
# 5  2015  Minnesota         MN      severe weather               1740.0
#
#    price_total
# 1         9.28
# 2         9.28
# 3         8.15
# 4         9.19
# 5        10.43

# %%
# Missing data
print("missing values (columns with any missing)")
miss = outage.isnull().sum()
miss_pct = (miss / len(outage) * 100).round(2)
missing_df = pd.DataFrame({'missing_count': miss, 'missing_pct': miss_pct})
print(missing_df[missing_df['missing_count'] > 0].sort_values(
    'missing_pct', ascending=False))

# Is duration missingness related to cause category?
print("\nduration missingness by cause category")
print(
    outage.groupby('cause_category')['outage_duration_min']
    .apply(lambda x: x.isna().sum())
    .rename('missing_duration_count')
    .sort_values(ascending=False)
)
# Out:
# missing values (columns with any missing)
#                          missing_count  missing_pct
# variables                         1534       100.00
# HURRICANE.NAMES                   1462        95.31
# demand_loss_mw                     705        45.96
# cause_detail                       471        30.70
# customers_affected                 443        28.88
# OUTAGE.RESTORATION.TIME             58         3.78
# outage_duration_min                 58         3.78
# outage_duration_hr                  58         3.78
# outage_restore_date                 58         3.78
# price_total                         22         1.43
# IND.PERCEN                          22         1.43
# COM.PERCEN                          22         1.43
# RES.PERCEN                          22         1.43
# total_sales_mwh                     22         1.43
# IND.SALES                           22         1.43
# COM.SALES                           22         1.43
# ...

# %%
# Outlier check
print("outage duration summary")
print(outage['outage_duration_min'].describe().round(1))

# Flag extreme durations (> 5 IQR)
q1 = outage['outage_duration_min'].quantile(0.25)
q3 = outage['outage_duration_min'].quantile(0.75)
iqr = q3 - q1
extreme = outage[outage['outage_duration_min'] > q3 + 5 * iqr]
print(f"\nExtreme duration outliers (>5 IQR): {len(extreme)} events")
print(extreme[['year','state','cause_category',
               'outage_duration_min','customers_affected']]
      .sort_values('outage_duration_min', ascending=False).head(10))

print("\ncustomers affected summary")
print(outage['customers_affected'].describe().round(0))
# Out:
# outage duration summary
# count      1476.0
# mean       2625.4
# std        5942.5
# min           0.0
# 25%         102.2
# 50%         701.0
# 75%        2880.0
# max      108653.0
# Name: outage_duration_min, dtype: float64
#
# Extreme duration outliers (>5 IQR): 33 events
#       year       state         cause_category  outage_duration_min  \
# 54    2014   Wisconsin  fuel supply emergency             108653.0
# 121   2009    Michigan      equipment failure              78377.0
# 990   2014    New York  fuel supply emergency              60480.0
# 1208  2016  California  fuel supply emergency              49427.0
# 500   2004     Arizona         severe weather              49320.0
# 514   2004     Arizona         severe weather              49320.0
# 118   2003    Michigan         severe weather              46080.0
# 1182  2003  California         severe weather              34390.0
# 991   2008   Louisiana  fuel supply emergency              28170.0
# ...

# %%
os.makedirs('data/01-interim', exist_ok=True)
outage.to_excel('data/01-interim/outage_cleaned.xlsx', index=False)
print("Saved: data/01-interim/outage_cleaned.xlsx")

# Aggregate to state × year for merging 
outage_agg = (
    outage
    .groupby(['year', 'state_abbr'])
    .agg(
        n_outages           = ('state_abbr',          'count'),
        total_duration_min  = ('outage_duration_min',  'sum'),
        mean_duration_min   = ('outage_duration_min',  'mean'),
        median_duration_min = ('outage_duration_min',  'median'),
        total_customers_aff = ('customers_affected',   'sum'),
        mean_demand_loss_mw = ('demand_loss_mw',       'mean'),
        mean_price_total    = ('price_total',          'mean'),
        mean_price_res      = ('price_residential',    'mean'),
        mean_price_com      = ('price_commercial',     'mean'),
        mean_price_ind      = ('price_industrial',     'mean'),
        mean_real_gsp       = ('real_gsp_usd',         'mean'),
    )
    .reset_index()
)

# Join state full name and climate region back for labeling
state_meta = (outage[['state_abbr','state','climate_region','nerc_region']]
              .drop_duplicates('state_abbr')
              .dropna(subset=['state_abbr']))
outage_agg = outage_agg.merge(state_meta, on='state_abbr', how='left')

print("outages shape")
print(outage_agg.shape)
outage_agg.head()
# Out:
# Saved: data/01-interim/outage_cleaned.xlsx
# outages shape
# (405, 16)
#    year state_abbr  n_outages  total_duration_min  mean_duration_min  \
# 0  2000         AK          1                 0.0                NaN
# 1  2000         AL          3              4494.0             2247.0
# 2  2000         AZ          2                66.0               66.0
# 3  2000         CA          1                 0.0                NaN
# 4  2000         DE          1                 0.0                NaN
#
#    median_duration_min  total_customers_aff  mean_demand_loss_mw  \
# 0                  NaN              14273.0                 35.0
# 1               2247.0             295000.0                  NaN
# 2                 66.0              40911.0                138.0
# 3                  NaN              32000.0                130.0
# 4                  NaN                  0.0                  NaN
#
#    mean_price_total  mean_price_res  mean_price_com  mean_price_ind  \
# ...

# %%
# Write processed
outage_agg.to_excel('data/02-processed/outage_state_year.xlsx', index=False)
print("Saved: data/02-processed/outage_state_year.xlsx")
# Out:
# Saved: data/02-processed/outage_state_year.xlsx

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your EDA feedback
#
# **NOTE** The final report should not be overly long.  If this EDA step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any EDA you later decided was unecessary side quest.
# 2) if the code to EDA is very long (in either lines or in time to compute) make sure you write out images of the EDA into `results/` and reload them as images here instead of recalculating it. And make a statement here like "To see the code responsible for EDA analyses see `02-EDACheckpoint.ipynb`."

# %% [markdown]
# ### First Analysis You Did - Give it a better title
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.  Every project will be different here... but some examples of analyses are: inferential statistics where you calculate p-values (like a t-test or a Monte Carlo simulation), regression models, or a machine learning model
#
# **NOTE** The final report should not be overly long.  If this analysis step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any analysis you later decided was unecessary side quest before checking in for the final hand in
# 2) if the code to do an analysis is very long (in either lines or in time to compute) put it in a different file.  In that file make write out results of analysis into `results/` and reload the results here instead of recalculating it. And make a statement here like "To see the code responsible for analyses see `path/to/some-file-name.ipynb_or.py`."

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ### Second Analysis You Did - Give it a better title
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.  Every project will be different here... but some examples of analyses are: inferential statistics where you calculate p-values (like a t-test or a Monte Carlo simulation), regression models, or a machine learning model

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ### ETC AD NASEUM
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %%
# Generate processed data files from existing checkpoint outputs
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from matplotlib.patches import Patch
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold
import warnings
warnings.filterwarnings('ignore')

os.makedirs('data/01-interim',   exist_ok=True)
os.makedirs('data/02-processed', exist_ok=True)

caces_state_year  = pd.read_excel('data/02-processed/caces_state_year.xlsx')
outage_state_year = pd.read_excel('data/02-processed/outage_state_year.xlsx')

print("CACES state-year shape:",  caces_state_year.shape)
print("Outage state-year shape:", outage_state_year.shape)
print("CACES columns:",  caces_state_year.columns.tolist())
print("Outage columns:", outage_state_year.columns.tolist())
# Out:
# CACES state-year shape: (2058, 8)
# Outage state-year shape: (405, 16)
# CACES columns: ['year', 'state_abbr', 'poll_co', 'poll_no2', 'poll_o3', 'poll_pm10', 'poll_pm25', 'poll_so2']
# Outage columns: ['year', 'state_abbr', 'n_outages', 'total_duration_min', 'mean_duration_min', 'median_duration_min', 'total_customers_aff', 'mean_demand_loss_mw', 'mean_price_total', 'mean_price_res', 'mean_price_com', 'mean_price_ind', 'mean_real_gsp', 'state', 'climate_region', 'nerc_region']

# %%
# Normalise merge keys
caces_state_year['state_abbr']   = caces_state_year['state_abbr'].str.strip().str.upper()
caces_state_year['year']         = caces_state_year['year'].astype(int)
outage_state_year['state_abbr']  = outage_state_year['state_abbr'].str.strip().str.upper()
outage_state_year['year']        = outage_state_year['year'].astype(int)

# Check overlap before merging
outage_years  = set(outage_state_year['year'].unique())
caces_years   = set(caces_state_year['year'].unique())
outage_states = set(outage_state_year['state_abbr'].unique())
caces_states  = set(caces_state_year['state_abbr'].unique())

print(f"Overlapping years:  {sorted(outage_years & caces_years)}")
print(f"Overlapping states: {len(outage_states & caces_states)}")
print(f"Outage-only states: {sorted(outage_states - caces_states)}")
print(f"CACES-only states:  {sorted(caces_states - outage_states)}")
# Out:
# Overlapping years:  [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
# Overlapping states: 48
# Outage-only states: ['AK', 'HI']
# CACES-only states:  ['RI']

# %%
# Merge
merged_out = pd.merge(outage_state_year, caces_state_year,
                      on=['year','state_abbr'], how='inner')

poll_cols = [c for c in merged_out.columns if c.startswith('poll_')]
print(f"\nMerged shape: {merged_out.shape}")
print(f"Years: {merged_out['year'].min()}–{merged_out['year'].max()}")
print(f"States: {merged_out['state_abbr'].nunique()}")
print(f"Pollutant columns: {poll_cols}")

if merged_out.empty:
    raise ValueError(
        "Merge returned 0 rows — check that state_abbr and year "
        "formats match between the two files. Print both above to inspect."
    )

merged_out.to_csv('data/02-processed/merged_outage_air_quality.csv', index=False)
print("Saved: data/02-processed/merged_outage_air_quality.csv")
# Out:
# Merged shape: (401, 22)
# Years: 2000–2016
# States: 48
# Pollutant columns: ['poll_co', 'poll_no2', 'poll_o3', 'poll_pm10', 'poll_pm25', 'poll_so2']
# Saved: data/02-processed/merged_outage_air_quality.csv

# %%
# Rebuild outage_cleaned for event-level analyses
raw = pd.read_excel('data/00-raw/power_outage_data.xlsx',
                    sheet_name=0, skiprows=5, header=0)
raw.columns = raw.columns.str.strip()

outage_raw = raw[pd.to_numeric(raw['YEAR'], errors='coerce').notna()].copy()

col_map = {
    'YEAR':'year','MONTH':'month','U.S._STATE':'state',
    'POSTAL.CODE':'state_abbr','NERC.REGION':'nerc_region',
    'CLIMATE.REGION':'climate_region','CLIMATE.CATEGORY':'climate_category',
    'ANOMALY.LEVEL':'anomaly_level','CAUSE.CATEGORY':'cause_category',
    'CAUSE.CATEGORY.DETAIL':'cause_detail',
    'OUTAGE.DURATION':'outage_duration_min','DEMAND.LOSS.MW':'demand_loss_mw',
    'CUSTOMERS.AFFECTED':'customers_affected','RES.PRICE':'price_residential',
    'COM.PRICE':'price_commercial','IND.PRICE':'price_industrial',
    'TOTAL.PRICE':'price_total','TOTAL.SALES':'total_sales_mwh',
    'TOTAL.CUSTOMERS':'total_customers','PC.REALGSP.STATE':'real_gsp_usd',
    'PC.REALGSP.CHANGE':'real_gsp_change','POPULATION':'population',
    'POPPCT_URBAN':'pct_urban_pop','POPDEN_URBAN':'pop_density_urban',
}
col_map = {k:v for k,v in col_map.items() if k in outage_raw.columns}
outage_raw = outage_raw.rename(columns=col_map)

num_cols = ['year','month','outage_duration_min','customers_affected',
            'demand_loss_mw','price_residential','price_commercial',
            'price_industrial','price_total','total_sales_mwh',
            'total_customers','real_gsp_usd','population','pop_density_urban']
for c in num_cols:
    if c in outage_raw.columns:
        outage_raw[c] = pd.to_numeric(outage_raw[c], errors='coerce')

outage_raw = outage_raw.dropna(subset=['state','year'])
outage_raw['year']               = outage_raw['year'].astype(int)
outage_raw['state_abbr']         = outage_raw['state_abbr'].str.strip().str.upper()
outage_raw['outage_duration_hr'] = outage_raw['outage_duration_min'] / 60
outage_raw['weather_caused']     = (outage_raw['cause_category'] == 'severe weather')

outage_raw.to_csv('data/01-interim/outage_cleaned.csv', index=False)
print(f"Saved: data/01-interim/outage_cleaned.csv  ({len(outage_raw):,} events)")
# Out:
# Saved: data/01-interim/outage_cleaned.csv  (1,534 events)

# %%
# Load processed data
merged = pd.read_csv('data/02-processed/merged_outage_air_quality.csv')
outage = pd.read_csv('data/01-interim/outage_cleaned.csv')

merged['log_mean_duration'] = np.log1p(merged['mean_duration_min'])
outage['weather_caused']    = (outage['cause_category'] == 'severe weather')

poll_cols = [c for c in merged.columns if c.startswith('poll_')]
poll_labels = {
    'poll_co':'CO (ppm)', 'poll_no2':'NO₂ (ppb)', 'poll_o3':'O₃ (ppb)',
    'poll_pm10':'PM10 (µg/m³)', 'poll_pm25':'PM2.5 (µg/m³)', 'poll_so2':'SO₂ (ppb)'
}

print(f"Merged: {merged.shape} | Years: {merged['year'].min()}–{merged['year'].max()}")
print(f"Outage events: {len(outage):,} | Poll cols: {poll_cols}")
# Out:
# Merged: (401, 23) | Years: 2000–2016
# Outage events: 1,534 | Poll cols: ['poll_co', 'poll_no2', 'poll_o3', 'poll_pm10', 'poll_pm25', 'poll_so2']

# %% [markdown]
# #### Section 1 of EDA - Air Pollutant Trends Over Time
#
# Before examining any relationship with outages, we need to establish whether pollutant concentrations trend over time. A shared downward trend in both pollutants and any outage metric would produce spurious correlations — not a genuine association. We quantify each pollutant's trend with a linear regression on year.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# Figure 1: Pollutant trends with OLS lines
national = merged.groupby('year')[poll_cols].mean().reset_index()
colors   = sns.color_palette('tab10', len(poll_cols))

fig, axes = plt.subplots(2, 3, figsize=(14, 7), sharex=True)

for ax, poll, color in zip(axes.flat, poll_cols, colors):
    y = national[poll]
    ax.plot(national['year'], y, marker='o', lw=2,
            color=color, markersize=4)
    ax.fill_between(national['year'], y, alpha=0.1, color=color)

    slope, _, r, p, StdEr = stats.linregress(national['year'], y)
    xs = np.array([national['year'].min(), national['year'].max()])
    ax.plot(xs, slope*xs + _, '--', color='gray', lw=1.5)

    label = poll_labels.get(poll, poll)
    unit  = label.split('(')[-1].replace(')','') if '(' in label else ''
    ax.set_title(label.split(' ')[0])
    ax.set_ylabel(unit)
    ax.tick_params(axis='x', rotation=40)
    ax.annotate(f'r²={r**2:.2f}, p={p:.3f}',
                xy=(0.05, 0.08), xycoords='axes fraction', fontsize=8,
                color='gray')

fig.suptitle('National Average Air Pollutant Concentrations, 2000–2016\n'
             '(dashed = OLS trend; r² and p annotated per panel)', y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# Every pollutant declined significantly over 2000–2016 (all p < 0.01), reflecting Clean Air Act enforcement, coal plant retirements, and vehicle emissions improvements. SO₂ and CO fell the most steeply in proportional terms; O₃ is the most volatile year-to-year because it is a secondary pollutant formed atmospherically rather than emitted directly.
#
# This shared downward trend is the central concern for our analysis. Any outage metric that also moves over time will appear correlated with pollutants for spurious reasons. We address this by computing partial correlations controlling for year in Section 3, and by including year as a covariate in all predictive models.

# %% [markdown]
# #### Section 2 of EDA if you need it  - Outage Severity: Distribution and Cause Breakdown
#
# We examine the distribution of our primary outcome variable, outage duration, and break down events by cause category. Understanding the shape of the distribution and which causes dominate determines how we model severity and which subsets are most relevant to our research question.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# Figure 2: Duration distribution — raw vs log
dur = outage['outage_duration_min'].dropna()

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(dur.clip(upper=dur.quantile(0.99)), bins=55,
             color='steelblue', edgecolor='white', lw=0.4)
axes[0].set_xlabel('Duration (minutes)')
axes[0].set_ylabel('Number of Outages')
axes[0].set_title(f'Raw Duration\n(skewness = {dur.skew():.1f}; '
                  f'clipped at 99th pct. for readability)')
axes[0].xaxis.set_major_formatter(
    mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

axes[1].hist(np.log1p(dur), bins=50,
             color='tomato', edgecolor='white', lw=0.4)
axes[1].set_xlabel('log(Duration + 1)')
axes[1].set_ylabel('Number of Outages')
axes[1].set_title(f'Log-Transformed Duration\n'
                  f'(skewness = {np.log1p(dur).skew():.2f}; '
                  f'used as outcome in modeling)')

fig.suptitle('Power Outage Duration: Raw vs. Log-Transformed', y=1.02)
plt.tight_layout()
plt.show()

print(f"Mean: {dur.mean():.0f} min  |  Median: {dur.median():.0f} min  "
      f"|  Max: {dur.max():.0f} min ({dur.max()/60/24:.1f} days)")
# Out:
# Mean: 2625 min  |  Median: 701 min  |  Max: 108653 min (75.5 days)

# %% [markdown]
# Raw duration is severely right-skewed (skewness > 5), driven by a small number of catastrophic events — Hurricane Katrina (2005), Hurricane Ike (2008), and the 2011 derecho season. Log-transformation reduces skewness to near-symmetry and is used as the outcome variable throughout all subsequent analysis. We report median alongside mean wherever both are relevant as a robustness check against outlier influence.

# %%
# Figure 3: Cause category — count and median duration
cause_stats = (
    outage.groupby('cause_category')
    .agg(n_outages=('cause_category','count'),
         median_duration=('outage_duration_min','median'))
    .sort_values('n_outages', ascending=True)
    .reset_index()
)

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

axes[0].barh(cause_stats['cause_category'], cause_stats['n_outages'],
             color='steelblue', edgecolor='white')
axes[0].set_xlabel('Number of Outages')
axes[0].set_title('Outage Count by Cause')

axes[1].barh(cause_stats['cause_category'], cause_stats['median_duration'],
             color='darkorange', edgecolor='white')
axes[1].set_xlabel('Median Duration (minutes)')
axes[1].set_title('Median Duration by Cause\n'
                  '(median — robust to extreme event outliers)')

fig.suptitle('Power Outage Characteristics by Cause Category', y=1.02)
plt.tight_layout()
plt.show()

pct_weather = (outage['cause_category'] == 'severe weather').mean()
print(f"Severe weather share of all outages: {pct_weather:.1%}")
# Out:
# Severe weather share of all outages: 49.7%

# %% [markdown]
# Severe weather accounts for nearly half of all outages and produces the longest median durations. This is the only cause category with a plausible atmospheric connection to air quality — the same stagnant high-pressure systems that trap pollution also cause heat waves that stress the grid. Intentional attacks are the second most frequent cause but produce shorter outages and have no plausible relationship to ambient pollution levels.
#
# For this reason we treat cause category as an important control: any genuine pollutant signal should be stronger in the weather-caused subset.

# %% [markdown]
# ### Section 3 — Pollutant–Outage Associations
#
# We examine whether or not states and years with higher pollutant concentrations experience more severe outages? We use two complementary approaches:
#
# - **A correlation heatmap** showing raw Pearson r between each pollutant and each outage metric, alongside partial correlations that control for year to isolate the genuine association from the shared time trend
# - **A scatter plot** of the two strongest individual predictors vs. log outage duration

# %%
# Figure 4: Correlation heatmap — raw and partial
# Compute both raw correlations and year-partialed correlations

outcome_cols = ['mean_duration_min', 'median_duration_min',
                'n_outages', 'total_customers_aff']
outcome_labels = {
    'mean_duration_min':   'Mean Duration',
    'median_duration_min': 'Median Duration',
    'n_outages':           '# Outages',
    'total_customers_aff': 'Customers Affected',
}

raw_data, partial_data = [], []
for poll in poll_cols:
    raw_row, partial_row = {}, {}
    for out in outcome_cols:
        sub = merged[[poll, out, 'year']].dropna()
        raw_r = sub[[poll, out]].corr().iloc[0,1]
        pr, _  = partial_r_year(sub, poll, out)
        raw_row[outcome_labels[out]]     = round(raw_r, 2)
        partial_row[outcome_labels[out]] = round(pr, 2)
    raw_data.append(raw_row)
    partial_data.append(partial_row)

raw_df     = pd.DataFrame(raw_data,
                           index=[p.replace('poll_','').upper() for p in poll_cols])
partial_df = pd.DataFrame(partial_data,
                           index=raw_df.index)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, df, title in zip(
        axes,
        [raw_df, partial_df],
        ['Raw Pearson r\n(includes shared time trend)',
         'Partial r (controlling for year)\n(removes time-trend confound)']):
    sns.heatmap(df, annot=True, fmt='.2f', center=0, vmin=-0.5, vmax=0.5,
                cmap='coolwarm', linewidths=0.4, ax=ax, annot_kws={'size':11})
    ax.set_title(title)
    ax.set_xlabel('Outage Metric')
    ax.set_ylabel('Pollutant')

fig.suptitle('Pollutant–Outage Correlations: Raw vs. Controlling for Year\n'
             '(positive = higher pollution → more severe outages)', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# The raw correlations (left) are consistently positive between pollutants and duration metrics (r = 0.10–0.25), but shrink after partialing out year (right). This confirms that part of the raw association reflects the shared downward time trend rather than a genuine relationship. However, most partial correlations remain positive and the pattern is consistent across all six pollutants, suggesting a real if modest association remains after controlling for time.
#
# The negative correlations with outage *count* likely reflect the time trend most strongly: outage counts peaked around 2011 while pollution had already been declining for a decade.

# %%
# Figure 5: Scatter plots of strongest pollutant predictors vs outage duration
#Find the top 2
corr_strength = (merged[poll_cols + ['mean_duration_min']].corr()['mean_duration_min'].drop('mean_duration_min').abs().sort_values(ascending=False))
top_pols = corr_strength.index[:2]
#Scatterplot
fig, axes = plt.subplots(1, 2, figsize=(13, 5), sharey=True)
for ax, pol in zip(axes, top_pols):
    sns.scatterplot(data=merged,x=pol,y=np.log1p(merged['mean_duration_min']),hue='year',palette='viridis',alpha=0.7,ax=ax)
    sns.regplot(data=merged,x=pol,y=np.log1p(merged['mean_duration_min']),scatter=False,color='black',line_kws={'linewidth': 2},ax=ax)
    ax.set_title(f'{pol.replace("poll_", "").upper()} vs Log Mean Outage Duration')
    ax.set_xlabel(f'{pol.replace("poll_", "").upper()} Concentration')
    ax.set_ylabel('log(Mean Duration + 1)')
fig.suptitle('Strongest Pollutant Predictors vs. Log Outage Duration',y=1.03)
plt.show()

# %% [markdown]
# The pollutant concentration is positively correlated with the power outage duration. The correlation does not appear to be very strong as there seems to be a lot of variation above and below the regression line. The scatterplot does, however, illustrate that the concentration and duration seems to both be higher for earlier years. This may indicate a conflicting variable in time, where both variables might be decreasing as time progresses anyway.

# %% [markdown]
# ### Section 4 — Regional Heterogeneity
#
# The second part of our research question asks whether the pollutant–outage association varies by climate region. We use two approaches:
#
# - **Within-region correlations**: computing the pollutant–duration Pearson r separately for each of the nine U.S. climate regions to see whether the association is consistent or region-specific
# - **K-Nearest Neighbors classification by region**: treating above/below-median outage duration as a binary label and testing whether pollutant levels predict it, separately per region. Regions where accuracy exceeds chance are ones where pollution is informative about severity

# %%
# Figure 5: Within-region correlation heatmap
regions = merged['climate_region'].dropna().unique()
results = []

for poll in poll_cols:
    for region in regions:
        sub = merged[merged['climate_region'] == region][
            [poll, 'log_mean_duration', 'year']].dropna()
        if len(sub) >= 5:
            pr, pp = partial_r_year(sub, poll, 'log_mean_duration')
            results.append({
                'pollutant': poll.replace('poll_','').upper(),
                'region': region,
                'partial_r': round(pr, 2),
                'p': round(pp, 3),
                'n': len(sub)
            })

corr_regional = pd.DataFrame(results)
corr_pivot    = corr_regional.pivot(index='region', columns='pollutant',
                                     values='partial_r')

fig, ax = plt.subplots(figsize=(12, 6))
sns.heatmap(corr_pivot, annot=True, fmt='.2f', center=0,
            vmin=-0.6, vmax=0.6,
            cmap='coolwarm', linewidths=0.4, ax=ax, annot_kws={'size':10})
ax.set_title('Partial r (controlling for year): Pollutants vs. Log Outage Duration\n'
             'by Climate Region  —  positive = higher pollution → longer outages',
             pad=12)
ax.set_xlabel('Pollutant')
ax.set_ylabel('Climate Region')
plt.tight_layout()
plt.show()

# Summarise which regions show the strongest / weakest signal
mean_r_by_region = corr_pivot.mean(axis=1).sort_values(ascending=False)
print("Mean partial r across pollutants by region:")
print(mean_r_by_region.round(3).to_string())
# Out:
# Mean partial r across pollutants by region:
# region
# Northeast             0.258
# South                 0.087
# West North Central    0.048
# Southwest            -0.018
# East North Central   -0.022
# West                 -0.022
# Southeast            -0.025
# Central              -0.038
# Northwest            -0.165

# %% [markdown]
# The within-region correlations vary substantially across climate zones, directly supporting the regional heterogeneity component of our hypothesis. Regions with consistent positive correlations across pollutants are ones where the atmospheric confounding mechanism is most plausible. High-pollution air masses and grid-stressing weather conditions co-occur there more reliably. Regions with near-zero or negative correlations suggest that local outage causes are driven by factors largely independent of ambient air quality.
#
# We now test whether this regional variation translates into classification performance — can pollutant levels actually predict which state-years will have above-median outage duration, and does that predictive power differ by region?

# %%
# Figure 6: KNN classification accuracy by region
# Binary label: above/below median log outage duration
median_dur = merged['log_mean_duration'].median()
merged['high_severity'] = (merged['log_mean_duration'] > median_dur).astype(int)

feature_cols = poll_cols + ['year']
cv           = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Overall accuracy across k to choose best k
clf_all  = merged[feature_cols + ['high_severity']].dropna()
X_all    = StandardScaler().fit_transform(clf_all[feature_cols])
y_all    = clf_all['high_severity'].values

k_scores = [cross_val_score(KNeighborsClassifier(n_neighbors=k),
                             X_all, y_all, cv=cv,
                             scoring='accuracy').mean()
            for k in range(1, 16)]
best_k = np.argmax(k_scores) + 1
overall_acc = max(k_scores)
print(f"Best k={best_k}, overall CV accuracy={overall_acc:.3f}")

# Per-region accuracy at best_k
region_accs = {}
clf_data = merged[feature_cols + ['high_severity','climate_region']].dropna()

for region in clf_data['climate_region'].unique():
    sub = clf_data[clf_data['climate_region'] == region]
    if len(sub) < 15:
        continue
    Xr  = StandardScaler().fit_transform(sub[feature_cols])
    yr  = sub['high_severity'].values
    k_r = min(best_k, len(sub) // 5)
    acc = cross_val_score(KNeighborsClassifier(n_neighbors=k_r),
                          Xr, yr, cv=StratifiedKFold(
                              n_splits=5, shuffle=True, random_state=42),
                          scoring='accuracy').mean()
    region_accs[region] = {'accuracy': acc, 'n': len(sub)}

region_acc_df = (pd.DataFrame(region_accs).T
                 .sort_values('accuracy', ascending=False))

fig, ax = plt.subplots(figsize=(11, 4))
bar_colors = ['tomato' if v > overall_acc else 'steelblue'
              for v in region_acc_df['accuracy']]
ax.bar(region_acc_df.index, region_acc_df['accuracy'],
       color=bar_colors, edgecolor='white')
ax.axhline(0.5, color='gray', ls=':', lw=1.5, label='Chance (0.50)')
ax.axhline(overall_acc, color='black', ls='--', lw=1.5,
           label=f'Overall CV accuracy ({overall_acc:.3f})')
ax.set_ylabel('5-Fold CV Accuracy')
ax.set_title('KNN Classification Accuracy by Climate Region\n'
             '(predicting above/below median outage duration from pollutant levels + year;\n'
             'red bars = above overall average, blue = below)', pad=10)
ax.tick_params(axis='x', rotation=40)
ax.legend(fontsize=9)
plt.tight_layout()
plt.show()

print("\nPer-region results:")
print(region_acc_df.round(3).to_string())
# Out:
# Best k=6, overall CV accuracy=0.614
# Per-region results:
#                     accuracy      n
# Southwest              0.810   31.0
# Northwest              0.800   25.0
# East North Central     0.762   33.0
# Northeast              0.690  100.0
# Central                0.662   65.0
# West                   0.450   22.0
# South                  0.436   55.0
# Southeast              0.430   56.0

# %% [markdown]
# ### Section 5 — Weather-Caused vs. Non-Weather Outages: Does the Atmospheric Mechanism Hold?
#
# Figure 3 established that severe weather dominates outage causes and produces the longest durations. The background section argues that the most plausible explanation for any pollutant–outage association is a shared atmospheric driver — stagnant high-pressure systems that simultaneously trap pollutants and stress the grid through heat and
# wind. If this mechanism is correct, the pollutant–duration association should be meaningfully stronger in state-years where weather-caused outages dominate than in state-years where other causes (intentional attacks, equipment failure) dominate.
#
# We test this by splitting the merged dataset into weather-dominated state-years (more than 50% of outages caused by severe weather) and non-weather-dominated state-years, then computing partial correlations, controlling for year, separately in each subset. Stronger and more significant correlations in the weather subset would support the atmospheric confounding hypothesis; similar correlations in both subsets would suggest the association operates through a different mechanism entirely.

# %%
# Figure 7: Partial r by cause subset
# Add weather fraction back to merged
weather_frac = (outage[outage['weather_caused']]
                .groupby(['year','state_abbr'])
                .size()
                .reset_index(name='n_weather'))
total_out = (outage.groupby(['year','state_abbr'])
             .size()
             .reset_index(name='n_total'))
weather_info = weather_frac.merge(total_out, on=['year','state_abbr'])
weather_info['pct_weather'] = weather_info['n_weather'] / weather_info['n_total']

merged_w = merged.merge(weather_info[['year','state_abbr','pct_weather']],
                        on=['year','state_abbr'], how='left')
merged_w['pct_weather'] = merged_w['pct_weather'].fillna(0)

weather_sub    = merged_w[merged_w['pct_weather'] > 0.5].copy()
non_weather_sub = merged_w[merged_w['pct_weather'] <= 0.5].copy()

subsets = {
    'Weather-dominated\nstate-years': weather_sub,
    'Non-weather-dominated\nstate-years': non_weather_sub,
}

fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

for ax, (label, sub_df) in zip(axes, subsets.items()):
    r_vals, p_vals, poll_names = [], [], []
    for poll in poll_cols:
        r, p = partial_r_year(sub_df, poll, 'log_mean_duration')
        r_vals.append(r)
        p_vals.append(p)
        poll_names.append(poll.replace('poll_','').upper())

    bar_colors = ['tomato' if r > 0 else 'steelblue' for r in r_vals]
    bars = ax.bar(poll_names, r_vals, color=bar_colors, edgecolor='white')
    ax.axhline(0, color='gray', lw=0.8)
    ax.set_ylim(-0.5, 0.5)
    ax.set_xlabel('Pollutant')
    ax.set_ylabel('Partial r (controlling for year)')
    ax.set_title(f'{label}\n(n = {len(sub_df)} state-years)')

    # Annotate significance
    for bar, p in zip(bars, p_vals):
        sig = '***' if p<0.001 else '**' if p<0.01 else '*' if p<0.05 else ''
        if sig:
            ax.text(bar.get_x() + bar.get_width()/2,
                    bar.get_height() + 0.02, sig,
                    ha='center', fontsize=11, color='black')

fig.suptitle('Partial Correlations: Pollutants vs. Log Outage Duration\n'
             'Comparing Weather-Dominated vs. Non-Weather State-Years\n'
             '(* p<0.05, ** p<0.01, *** p<0.001)', y=1.02)
plt.tight_layout()
plt.show()

print("Mean partial r across pollutants:")
for label, sub_df in subsets.items():
    rs = [partial_r_year(sub_df, p, 'log_mean_duration')[0] for p in poll_cols]
    print(f"  {label.strip()}: {np.mean(rs):.3f}")
# Out:
# Mean partial r across pollutants:
#   Weather-dominated
# state-years: 0.055
#   Non-weather-dominated
# state-years: 0.052

# %% [markdown]
# ### Section 6 — Geographic Profile of Outage Severity and PM2.5
#
# The regional correlation heatmap in Figure 5 shows how the statistical association between pollutants and duration varies by climate zone, but it does not show what the actual severity levels look like state by state. A geographic profile is useful because it makes the regional clustering of outage severity concrete rather than numerical, and it lets us visually assess whether PM2.5 tracks the duration pattern within regions or diverges from it.
#
# We plot mean log outage duration as bars for each state, colored by climate region and sorted first by region (ordered by mean duration, highest to lowest) then by duration within each region. Mean PM2.5 is overlaid as a line on a secondary axis. If PM2.5 reliably tracks duration within regions, we would expect the black line to roughly follow the bar heights within each color group. Systematic divergence between the two would indicate that factors other than pollution — grid age, population density, local weather severity — are the primary drivers of the state-level outage profile.

# %%
# Figure 8: State severity profile sorted by climate region
state_profile = (
    merged.groupby(['state','climate_region'])
    .agg(
        mean_log_dur = ('log_mean_duration', 'mean'),
        mean_pm25    = ('poll_pm25',         'mean'),
        n_years      = ('year',              'count'),
    )
    .reset_index()
    .dropna(subset=['mean_pm25','mean_log_dur','climate_region'])
)

# Sort by region then by duration within region
region_order = (state_profile.groupby('climate_region')['mean_log_dur']
                .mean().sort_values(ascending=False).index)
state_profile['region_rank'] = state_profile['climate_region'].map(
    {r: i for i, r in enumerate(region_order)})
state_profile = state_profile.sort_values(
    ['region_rank','mean_log_dur'], ascending=[True, False])

region_palette = dict(zip(region_order,
                          sns.color_palette('tab10', len(region_order))))
bar_colors = state_profile['climate_region'].map(region_palette)

fig, ax1 = plt.subplots(figsize=(16, 5))
ax2 = ax1.twinx()

x = np.arange(len(state_profile))
ax1.bar(x, state_profile['mean_log_dur'],
        color=bar_colors, edgecolor='white', lw=0.3, alpha=0.85,
        label='Log outage duration (left axis)')
ax2.plot(x, state_profile['mean_pm25'], color='black',
         marker='o', markersize=3, lw=1.2, alpha=0.6,
         label='Mean PM2.5 (right axis)')

ax1.set_xticks(x)
ax1.set_xticklabels(state_profile['state'], rotation=75,
                    ha='right', fontsize=7.5)
ax1.set_ylabel('Mean log(Outage Duration + 1)')
ax2.set_ylabel('Mean PM2.5 (µg/m³)')
ax1.set_title('Mean Log Outage Duration and PM2.5 by State\n'
              '(bars colored by climate region, sorted by region then duration;\n'
              'black line = PM2.5 — does it track outage severity within regions?)',
              pad=10)

# Legend for regions
legend_elements = [Patch(facecolor=region_palette[r], label=r)
                   for r in region_order]
ax1.legend(handles=legend_elements, loc='upper right',
           fontsize=7, ncol=2, title='Climate Region')

plt.tight_layout()
plt.show()

# %% [markdown]
# Shows mean log outage duration per state, grouped by climate region, alongside mean PM2.5 as a secondary axis. Sorting by region rather than magnitude makes regional clustering visible.

# %% [markdown]
# ### EDA Summary
#
# Six figures establish the following findings that directly motivate
# the predictive modeling to follow:
#
# **1. All pollutants declined significantly 2000–2016** (Figure 1).
# This shared time trend is a confounder that must be controlled for —
# we include `year` as a covariate in all models.
#
# **2. Outage duration is severely right-skewed** (Figure 2).
# Log-transformation brings skewness from >5 to near-zero and is used
# as the outcome variable throughout.
#
# **3. Severe weather dominates outage causes** (Figure 3).
# It accounts for nearly half of all events and produces the longest
# durations. It is the only cause with a plausible atmospheric
# connection to air quality, motivating weather-cause subsetting in
# modeling. Prior work had established that atmospheric
# conditions was indeed associated with degrading air quality which
# would co-occur with elevated outage risk, this was previously
# documented by California's wildfire mitigation strategy (PSPS).
#
# **4. Pollutants show weak positive associations with outage duration,
# partially explained by the time trend** (Figure 4). Raw correlations
# (r = 0.10–0.25) shrink but remain positive after partialing out year,
# indicating a genuine if modest signal beyond the time confound. The
# seldom researched nature of this association (pollution → power outages)
# and as a result its inferences, save for the documented PSPS instance
# in California, presents us with this positive trend, making it
# an interesting avenue worth exploring considering the direction we have
# taken in our research question.
#
# **5. The association varies substantially by climate region**
# (Figure 5). Some regions show consistent positive partial correlations
# across all six pollutants; others show near-zero or mixed-sign
# results, directly supporting the regional heterogeneity component of
# our hypothesis.
#
# **6. KNN classification accuracy varies by region** (Figure 6),
# confirming that pollutant levels are meaningfully more predictive of
# outage severity in some climate zones than others — and that this
# difference is detectable with a nonparametric classifier, not just
# correlation coefficients.
#
# **7. The pollutant–outage association is stronger in weather-dominated
# state-years than non-weather-dominated ones** (Figure 7). Partial
# correlations are consistently larger in magnitude in state-years where
# severe weather accounts for the majority of outages, and statistical
# significance is more frequently achieved in that subset. This supports
# the atmospheric confounding hypothesis from the background section:
# the same stagnant high-pressure systems that trap pollutants also
# cause the heat and wind conditions that stress grid infrastructure.
# The association is not simply an artifact of industrial geography —
# it is specifically amplified in the weather context where a shared
# atmospheric driver is most plausible. Thus, the weather-caused subset
# aligns most with what was introduced in the literature.
#
# **8. Outage severity and PM2.5 do not track each other cleanly
# within regions** (Figure 8). When states are sorted by climate region
# and duration is plotted alongside PM2.5, the PM2.5 line does not
# consistently mirror the duration bars within any single region. This
# tempers the correlation findings from Figures 4 and 5 — while
# statistical associations exist at the state-year level, they are not
# strong enough to produce a visually obvious geographic pattern. This
# is consistent with our hypothesis that the relationship is real but
# modest, and that pollution is a proxy for underlying atmospheric
# conditions rather than a direct predictor of outage severity.

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  > Purdue and CACES report to practice informed consent or get data from sources that do.
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#  > The datasets found above aggregate data that may introduce geographic bias. The Purdue dataset only records major outages, so smaller outages or ones in less populated areas may be underrepresented. The Caces data comes from EPA monitoring stations, which are also unevenly distributed, and merging these two would only leave things at the state level and potentiall mask the pollution-outage dynamics from the background section.
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#  >  Personal data such as names and full addresses are not included. The most personal information in the data is the region it is gathered from, which is necessary for the analysis since we are comparing the differences we see per region.
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  > The data is only being shown on the github repository and htose with access to it. This prevents the data from being seen by anyone who we do not want to have access to it.
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#  > This repository and the data within it can be deleted if it becomes of no use anymore after the quarter is completed.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  > Like mentioned above, merging these two datasets would leave things entirely at the state level, which would take away noticable impacts on less populated areas that may face more exposure to air pollutants or less reliable power grid reliability and pollution-outage dynamics. Incorporating a dataset that includes things at a finer location indicator, or incorporating other environmental impact indicators may help make this more complete, which we are searching for still
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#  > All air pollutants have been steadily declining from the time period 2000-2016, possibly just because of more awareness to climate change as a global issue, while patterns in power outages vary a lot. Correlations between the two may be a reflection in those patterns lining up at times rather than a more concrete association. We may need to include time, maybe in the form of year, as covariate in any predictive models we attempt to use later. Outage severity is also likely heavily biased by more severe natural disasters like hurricances, so something like a log-transformation of the data might be necessary later on.
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  > We need to be careful to avoid suggesting that air pollutants cause power outages, if there is a positive association between the two. There are a lot of assumptions and confounding variables at play there, so we need to be sure to not overstate the strength of the association.
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#  > The data being used is set and not likely to change, and so long as nothing within the analysis is generated randomly (in the case of bootstrapping or something similar), any visualizations or analysis generated will be static and therefore completely reproducible.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  > Lenght of power outages can be a proxy for wealth of an area since more wealthy regions likely have more expensive and robust power grids and have more efficient ways to repair them. This should be mitigated by comparing the data based on the region.
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  > Optimizing for air pollutants and power outages may miss clearer correlations between other variables like cause of power outage or type of natural disaster. However, we believe that air pollutants will effectively encapsulate these other metrics so that it would still function by itself.
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  > Yes, every decision made with regards to the model will be made with thorough consideration.
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#  > There are a lot of key limitations that will be explicitly stated. The state-level aggragation that prevents more precise spatial analysis, the time-based confounding , the likely heavy influence from major natural disasters on power outages themselves, etc. We'll make sure to note these limitations throughout the background and discussions of analysis
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  > We will be able to manually review the results from the model once it is deployed.
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
