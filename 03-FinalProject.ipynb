# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report section Title & Abstract trhough Data Wrangling:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#
# For the report section Data Visualizations through Documentation and Written Communication:
# - Each Developing  => -1 pts
# - Each Unsatisfactory/Missing => -2 pts
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# Until the score is 0
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Ethics                                                                             | No effort or just says we have no ethical concerns                                                                                                                                                                                                                                                  | Minimal ethical section; probably just talks about data privacy and no unintended consequences discussion. Ethical concerns raised seem irrelevant.                                                                                                                                                 | The ethical concerns described are appropriate and sufficiently                                                                                                                                                                                                                                                                     | Ethical concerns are described clearly and succinctly. This was clearly a thorough and nuanced approach to the issues                                                                                                                                                                                                          |
# | Data visualizations                                                                | No plots. Or most plots don't capture useful information, or their display of information is difficult to understand. Legends, labels, axes, titles, captions, etc of most plots may be poor or missing. Most figures are not referenced in the main text.                                          | Fewer than 3 relevant plots (irrelevant to the question plots do not count).  Or a few of the plots don't make sense or capture useful information. Legends, labels, axes, titles, captions, etc are illegible or inadequately describe the content in a few figures. Or a few figures are not referenced or explained inside the main text. | Plots almost all make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | No analyses beyond EDA style explorations of the dataset. Or analyses presented do not help address the question/hypothesis. Or most of the analyses presented are not technically approriate (eg. using parametric methods for non-parametric data).                                              | Only one analysis beyond EDA. Or a few analyses presented do not address the question/hypothesis. Or a few of the analyses presented are not technically approriate                                                                                                                                                                  |  At least two analyses beyond EDA. That is, the project uses two different techniques (e.g., inference vs machine learning; or t-test vs regression; or entire dataset vs stratified) or two different proxies for the same concept are investigated.  Each analysis addressed the question/hypothesis and is technically approriate. | Many different analyses are used. Each analysis addressed an aspect of the question/hypothesis and is technically approriate. Perhaps they use multiple datasets, or do something else to go the extra mile and address the reliability of the results                                            |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project - Air Pollution and Power Outage Severity in the Continental United States
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# This project investigates whether ambient air pollutant concentrations predict the severity of major power outages across the continental United States, and whether that relationship varies by climate region. While prior literature has established that outages worsen air quality (via diesel generator use and increased traffic), the inverse direction — pollution predicting outage severity — is substantially less studied. We merge two complementary public datasets: the CACES annual county-level air quality estimates (2000–2016) and the Purdue Major Power Outage dataset (1,534 events, 2000–2016), joined at the state × year level. Six EPA criteria pollutants (CO, NO₂, O₃, PM10, PM2.5, SO₂) serve as predictors, where log-transformed outage duration is the primary outcome.
#
# Exploratory analysis reveals that all pollutants declined significantly over the study period. After partialing out year, modest positive partial correlations remain between pollutant levels and outage duration. These associations are meaningfully stronger in state-years where severe weather dominates outage causes, supporting the hypothesis that a shared atmospheric driver simultaneously traps pollutants and stresses grid infrastructure. Regional heterogeneity is substantial: some climate zones show consistent positive partial correlations across all pollutants, while others show near-zero or mixed results. KNN classification confirms that pollutant levels carry predictive signal for above/below-median outage severity in several regions but not uniformly.
#
# Overall, the evidence supports a real but modest association between ambient pollution and outage severity, most plausibly explained by shared atmospheric confounding rather than a direct causal pathway from pollution to infrastructure failure. The findings motivate further research with finer spatial resolution and weather-controlling covariates.

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# - Manning Karahashi: Analysis, Experimental investigation, Software
# - Emily Nguyen: Project administration, Writing - original draft, Writing - review and editing
# - Christian Paddie: Background research, Conceptualization
# - Lucas Vocelka: Data curation, Experimental investigation
# - Andrew Gooboian: Methodology, Software, Visualization

# %% [markdown]
# ## Research Question

# %% [markdown]
# Is a rise in air pollutants accompanied by an increase in the severity (length/cost) of a power outage in the continental United States of America, and do these predictors change by region?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# &emsp;In the United States, air quality is monitored and defined by the Environmental Protection Agency (EPA) responsible for the protection of human health as well as environment. Air quality is characterized as the concentration of specific pollutants in the atmosphere and their resulting effects on the health of the public/environment. The EPA’s Air Quality Index (AQI) ranges from “Good” to “Hazardous” where the severity of pollutant diffusion across the atmosphere poses little risk to the public (“Good”) to everyone being increasingly likely to experience adverse effects from its exposure (“Hazardous”). The AQI’s index values intuitively rate air quality by having a higher AQI value meaning the greater the level of air pollution and vice versa.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) It is important to note however that the AQI is a composite measure and takes multiple air pollutants into account rather than just an individual pollutant concentration.
#
# &emsp; As the relationship between power outages and air pollution is concerned, previous work has been done in Ecuador, specifically in the capital, Quito, and their 2023 and 2024 power outages which saw large scale blackouts for several hours for consecutive months. Researchers Vallejo and their colleagues posit that Quito’s blackouts, “...revealed a significant deterioration in atmospheric pollution, primarily driven by the widespread use of diesel generators, increased vehicular traffic, and adverse meteorological conditions…”<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) Vallejo and colleagues’ work in the context of Ecuador’s 2023 and 2024 power outages reveals an interesting interaction between infrastructural issues such as blackouts and the increased usage of alternative power sources which produce pollutants and deteriorate the atmosphere. Another work that explores the relationship between air pollution and power outages takes a similar look at how Delhi, India and its citizens grapple with power outages through reliance on backup solutions like diesel generators. Yatang Lin and Dana Kassem note that diesel generators “...emit 3.5 times more nitrogen oxides and two times more particulate matter than coal-fired plants for the same amount of energy,” which is worsened by the fact that Delhi’s power outages are locally combatted through “The frequent on-off cycling of backup generators…” which “...further increases fuel consumption and pollution,”<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) Lin and Kassem’s findings further display the downstream pollutive effects of power outages and how they influence worsening air quality. This explains a possible reasoning as to why air pollutants and strength of power outage could be correlated. This correlation found in this work is the type of relationships we wish find with our research question. To be subject to frequent blackouts and power outages coupled with a reliance on alternative power sources which negatively impact air quality establishes this relationship wherein power outages can possibly predict worsening air quality/pollution.
#
# &emsp; An important consideration when discussing air quality involves the health complications that come with exposure to air pollutants. As detailed by California’s Air Resources Board, the reliance on backup generators (which are primarily diesel generators) and their emission of diesel particulate matter (DPM) is considered a toxic air contaminant implicated in the development of cancer and increasing the lung’s susceptibility to damage.<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4) The ability for air pollution and power outages to influence one another has an impact on health either way through exposure to harmful airborne substances or as how Zhang and colleagues put it, power outages threaten vulnerable populations as they suggest an increased risk of COPD exacerbation, as a result of their dependency on electricity.<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5) The importance of air quality and power reliability and its influences on the health of the public cannot be understated. The relationship established in the Quito and Delhi examples (failing power infrastructure predicting worsening air quality) can be explored in the United States as well, a particular pathway of interest to prevent this type of event is the initiation of public safety power shutoffs (PSPS) performed in California to proactively prevent wildfires by electrical infrastructure. Huang and colleagues frame PSPS "As one of the most critical wildfire mitigation strategies, PSPS, present a strong interaction between wildfires, electric infrastructure, and customers,"<a name="cite_ref-6"></a>[<sup>6</sup>](#cite_note-6) Huang and colleagues' in examining California's unique interaction with its dry climate which exacerbate the catastrophic nature of wildfires sparked through electrical infrastructure failures, establishes that outage severity is correlated with an electrical system's potential for harm environmentally through wildfires which are extensively documented to negatively impact air quality. Not to mention dry heat and windy weather conditions, which are commonly experienced in California, independently and simultaneously impact air quality in tandem with increasing the risk of a PSPS to prevent wildfires by virtue of failing electrical equipment.
#
# &emsp; We are already made well aware that power outages/failing electrical infrastructure can influence air quality (evidenced above), but we wish to examine if air pollution is able to have a statistically significant correlation with power outage severity, the temporality of the two issues essentially being swapped with what was observed in the background research. Prior work has established that outages cause pollution (A→B); we are testing whether pollution predicts outage severity (B→A). This project examines the relationship between air pollution and power outages within the context of the United States and intends to explore the inverse of the previously established case studies done in Quito and Delhi. We intend to examine if air pollutants are a predictor for the severity (length/cost) of power outages nationally, and if these predictors (specific air pollutants) are subject to variability per US region. This project intends on leaning into the fact that air quality predicting power outage events or at least having a correlation to an outage's severity is seldom researched. The previously established relationships are very intuitive and easy to think about as having electricity is a necessity in this day and age, thus it is nigh unto instinctual that people search for alternatives to maintain the luxuries and the way of life brought about through electricity through alternative power sources regardless of its harms on air quality or its capacity for pollution. Possible avenues can be explored in examing the correlation we wish to establish between air pollution and power outage severity. For instance, is it possible that the widely accepted and proven relationship that air pollution has on the degradation on the climate of an area may affect electrical infrastructure and cause fires which resultantly influence air quality, or damaged/heavily polluted climates may require more energy usage to make living tolerable which puts stress on these areas' power grids. These are very interesting potential explanations for the relationship we want to examine, but of course none of these can be causally established with the tools we decided to implement, they just provide us with possible areas of observation/interest. Limiting the scope to the United States was decided on account of the fact that the entire continental US has a diverse array of natural environments, varying degrees of urban sprawl and suburban areas, and with regions with their own power grids, thus we are sourcing from data that would be more robust than collecting by county and more focussed than collecting by continent.
#
# &emsp; The data sources we use reflect these two sides of the relationship directly. The CACES dataset operationalizes ambient air quality through the same six criteria pollutants — CO, NO₂, O₃, PM10, PM2.5, and SO₂ — that compose the EPA's AQI described above, providing annual population-weighted concentration estimates at the county level across the full study period.<a name="cite_ref-7"></a>[<sup>7</sup>](#cite_note-7) The Purdue Major Power Outage dataset operationalizes outage severity through duration, customers affected, and demand loss and includes cause category and climate region classifications that allow us to test whether any association is specific to weather-caused events (the subset where shared atmospheric drivers are most plausible) and whether it varies across the nine U.S. climate zones documented by Mukherjee and colleagues.<a name="cite_ref-8"></a>[<sup>8</sup>](#cite_note-8) Neither dataset alone can address our research question, the contribution of this analysis is specifically in the merger of the two, linking ambient pollution levels to outage outcomes in the same state and year, and examining whether that linkage is consistent or region-dependent. It is worth noting that weather operates as a likely confounder throughout this analysis — atmospheric conditions independently influence both air quality and power outage risk in ways that are difficult to fully separate. Our subgroup analysis of weather-caused outages helps isolate the events where this overlap is most direct.
#
# **References**
# 1. <a name="cite_note-1"></a>[^](#cite_ref-1) AirNow. *Air Quality Index (AQI) Basics*. https://www.airnow.gov/aqi/aqi-basics/
# 2. <a name="cite_note-2"></a>[^](#cite_ref-2) Vallejo, Fidel., et al. (26 Feb 2025) Prolonged Power Outages and Air Quality: Insights from Quito's 2023-2024 Energy Crisis. *atmosphere*. https://www.mdpi.com/2073-4433/16/3/274#:~:text=Traffic%20emissions%2C%20especially%20from%20diesel,composition%20%5B5%2C6%5D.
# 3. <a name="cite_note-3"></a>[^](#cite_ref-3) Lin, Yatang., Kassem, Dana. (4 Jan 2025) The environmental cost of power outages: Evidence from Delhi. *Journal of Public Economics*. https://www.sciencedirect.com/science/article/pii/S0047272724002251
# 4. <a name="cite_note-4"></a>[^](#cite_ref-4) California Air Resources Board. Use of Back-up Engines for Electricity Generation During Public Safety Power Shutoff Events. https://ww2.arb.ca.gov/resources/documents/use-back-engines-electricity-generation-during-public-safety-power-shutoff
# 5. <a name="cite_note-5"></a>[^](#cite_ref-5) Zhang, Wangjian., et al. (Dec 2020) Power Outage An Ignored Risk Factor for COPD Exacerbations. "CHEST" https://pmc.ncbi.nlm.nih.gov/articles/PMC7768937/pdf/main.pdf
# 6. <a name="cite_note-6"></a>[^](#cite_ref-6) Huang, Can., et al. (Sept 2023) A Review of Public Safety Power Shutoffs (PSPS) for Wildfire Mitigation: Policies, Practices, Models and Data Sources. *IEEE* https://ieeexplore.ieee.org/document/10154121
# 7. <a name="cite_note-7"></a>[^](#cite_ref-7) CACES (Center for Air, Climate, and Energy Solutions). *U.S. Census Tract-Level Air Quality Data*. https://www.caces.us/data
# 8. <a name="cite_note-8"></a>[^](#cite_ref-8) Mukherjee, S., Nateghi, R., & Hastak, M. (2018). A multi-hazard approach to assess severe weather-induced major power outage risks in the U.S. *Reliability Engineering & System Safety*, 175, 283–305. https://doi.org/10.1016/j.ress.2018.03.015

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that air pollutant concentrations will show a positive correlation with power outage severity, measured primarily by outage duration, and that the strength of this association will vary meaningfully by climate region. The causation between air quality and power infrastructure tends to run from outages worsening pollution rather than the other way. This prediction is grounded in the idea that severe weather dominates outage causes, particularly in the midwest/southern parts of the US, and on the assumption that air pollutants are a general indicator of climate change as a whole, which is linked to severe weather events.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# Our research question has two distinct components: (1) whether air pollutant levels predict power outage severity, and (2) whether these predictors vary by region. Answering it requires one dataset that measures ambient air pollution across U.S. states over time, and a separate dataset that records the severity, cause, and geographic location of power outage events over the same period. The CACES data has no outage information, and the Purdue data has no air quality measurements, so both are strictly necessary for this analysis. The analysis depends on merging them into a single state × year dataset where both pollution levels and outage metrics are jointly observed.
#
# **CACES U.S. Air Quality Data** (https://www.caces.us/data) provides the air pollution side of the analysis. It supplies annual, county-level, population-weighted ambient concentration estimates forten pollutants — CO, NO₂, O₃, BC, PM10, PM2.5, SO₂, COA, HOA, and PNC — covering 1979–2020. Key columns are `fips` (county identifier), `pollutant`, `year`, `pred_wght` (the population-weighted concentration estimate), `state_abbr`, `lat`, and `lon`. Estimates are derived from EPA monitoring networks combined with land-use regression models, providing coverage even for counties without physical monitoring stations. Population-weighting means the estimate reflects the exposure experienced by an average resident of that county rather than a simple geographic average, making it more meaningful for health and policy analysis than a raw spatial mean.
#
# Because the outage dataset records location only at the state level, we aggregate CACES county estimates to annual state means using `state_abbr` and `year` as keys. This loses within-state spatial variation but produces a common geographic identifier for merging. Four of the ten pollutants (BC, COA, HOA, PNC) have sparse coverage that does not overlap with the outage dataset's 2000–2016 window after merging, and are excluded from modeling — leaving CO, NO₂, O₃, PM10, PM2.5, and SO₂ as the six predictors used in analysis. These six are also the primary components of the EPA's AQI described in the background, making them the most policy-relevant measures available.
#
# **Purdue Major Power Outage Risks in the U.S.** (https://engineering.purdue.edu/LASCI/research-data/outages) provides the outage severity side of the analysis. It records 1,534 major power outage events in the contiguous U.S. from January 2000 to July 2016, with one row per event. The variables we use as outage severity outcomes are `OUTAGE.DURATION` (minutes) and `CUSTOMERS.AFFECTED` — directly measuring how long and how widely each outage impacted the grid. `DEMAND.LOSS.MW` provides a third severity measure reflecting peak grid stress. `CAUSE.CATEGORY` is critical for our analysis because severe weather is the only cause with a plausible atmospheric connection to air quality — we use it to subset analyses and test whether the pollutant-outage association is stronger in weather-caused events specifically. `CLIMATE.REGION` (nine U.S. climate zones) is the primary variable for the regional heterogeneity component of our question, allowing us to test whether pollutant-outage associations differ across climate zones. Sector-level electricity prices (`RES.PRICE`, `COM.PRICE`, `IND.PRICE`, `TOTAL.PRICE`) serve as economic control variables rather than outcomes, since they reflect state energy market conditions rather than outage-specific severity.
#
# Because outage events are recorded individually but CACES is annual and state-level, we aggregate outage events to state × year means and counts before merging. The two datasets are joined on `state_abbr` and `year` using an inner join, retaining only state-years present in restricting the analysis to 2000–2016 across the contiguous 48 states. The merged dataset is the sole input to all EDA and modeling: CACES contributes the six pollutant concentration columns, and the Purdue data contributes the outage severity metrics, cause breakdown, and climate region classification.

# %% [markdown]
# ### Data Wrangling
#
# The full wrangling pipeline was developed and validated in `02-EDACheckpoint.ipynb`. The cells below reproduce the essential steps to load, clean, and produce the processed files used in all subsequent analyses.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('./modules')

import pandas as pd
import numpy as np
import os
import get_data

import warnings
warnings.filterwarnings('ignore')

os.makedirs('data/00-raw',       exist_ok = True)
os.makedirs('data/01-interim',   exist_ok = True)
os.makedirs('data/02-processed', exist_ok = True)

datafiles = [
    {
        'url': 'https://docs.google.com/spreadsheets/d/1eP7XIrHZv4AiFUk-YISoRdKlYedUAstW/export?format=xlsx',
        'filename': 'power_outage_data.xlsx'
    },
    {
        'url': 'https://docs.google.com/spreadsheets/d/1mNQ2BhRzK5MApRL1XiINT4zxwkdDp79m/export?format=xlsx',
        'filename': 'caces_us_data.xlsx'
    }
]

get_data.get_raw(datafiles, destination_directory = 'data/00-raw/')
# Out:
# Overall Download Progress:  50%|█████     | 1/2 [00:00<00:00,  1.18it/s]
# Successfully downloaded: power_outage_data.xlsx
# Overall Download Progress: 100%|██████████| 2/2 [00:04<00:00,  2.09s/it]
# Successfully downloaded: caces_us_data.xlsx

# %% [markdown]
# ### Dataset #1 - CACES U.S. Air Quality

# %%
caces_raw = pd.read_excel('data/00-raw/caces_us_data.xlsx')
caces = caces_raw.copy()
caces.columns = caces.columns.str.strip().str.lower()

# Restrict to the 6 well-covered pollutants
pollutants = ["co", "no2", "o3", "pm10", "pm25", "so2"]
caces_filtered = caces[caces['pollutant'].str.lower().isin(pollutants)].copy()
caces_filtered['pollutant'] = caces_filtered['pollutant'].str.lower()

# Aggregate to population-weighted mean across counties
state_yr_long = (
    caces_filtered
    .groupby(['year', 'state_abbr', 'pollutant'])['pred_wght']
    .mean()
    .reset_index()
)

state_yr = (
    state_yr_long
    .pivot_table(index = ['year','state_abbr'], columns = 'pollutant', values = 'pred_wght')
    .reset_index()
)

state_yr.columns.name = None
state_yr = state_yr.rename(columns = {p: f'poll_{p}' for p in pollutants})
state_yr['state_abbr'] = state_yr['state_abbr'].str.strip().str.upper()
state_yr['year'] = state_yr['year'].astype(int)

state_yr.to_excel('data/02-processed/caces_state_year.xlsx', index = False)

# %% [markdown]
# ### Dataset #2  - Purdue Major Power Outages

# %%
purdue_raw = pd.read_excel(
    'data/00-raw/power_outage_data.xlsx',
    sheet_name = 0, skiprows = 5, header = 0
)
purdue_raw.columns = purdue_raw.columns.str.strip()
outage = purdue_raw[pd.to_numeric(purdue_raw['YEAR'], errors = 'coerce').notna()].copy()

# Rename columns
col_map = {
    'YEAR'                    : 'year',
    'MONTH'                   : 'month',
    'U.S._STATE'              : 'state',
    'POSTAL.CODE'             : 'state_abbr',
    'NERC.REGION'             : 'nerc_region',
    'CLIMATE.REGION'          : 'climate_region',
    'CLIMATE.CATEGORY'        : 'climate_category',
    'ANOMALY.LEVEL'           : 'anomaly_level',
    'CAUSE.CATEGORY'          : 'cause_category',
    'CAUSE.CATEGORY.DETAIL'   : 'cause_detail',
    'OUTAGE.DURATION'         : 'outage_duration_min',
    'DEMAND.LOSS.MW'          : 'demand_loss_mw',
    'CUSTOMERS.AFFECTED'      : 'customers_affected',
    'RES.PRICE'               : 'price_residential',
    'COM.PRICE'               : 'price_commercial',
    'IND.PRICE'               : 'price_industrial',
    'TOTAL.PRICE'             : 'price_total',
    'TOTAL.SALES'             : 'total_sales_mwh',
    'TOTAL.CUSTOMERS'         : 'total_customers',
    'PC.REALGSP.STATE'        : 'real_gsp_usd',
    'PC.REALGSP.CHANGE'       : 'real_gsp_change',
    'POPULATION'              : 'population',
    'POPPCT_URBAN'            : 'pct_urban_pop',
    'POPDEN_URBAN'            : 'pop_density_urban',
    'OUTAGE.START.DATE'       : 'outage_start_date',
    'OUTAGE.RESTORATION.DATE' : 'outage_restore_date',
}
col_map = {k: v for k, v in col_map.items() if k in outage.columns}
outage = outage.rename(columns = col_map)

# Numeric coercion 
num_cols = [
    'year', 'month', 'outage_duration_min', 'customers_affected',
    'demand_loss_mw', 'price_residential', 'price_commercial',
    'price_industrial', 'price_total', 'total_sales_mwh',
    'total_customers', 'real_gsp_usd', 'population', 'pop_density_urban',
]
for c in num_cols:
    if c in outage.columns:
        outage[c] = pd.to_numeric(outage[c], errors = 'coerce')

outage = outage.dropna(subset = ['state', 'year'])
outage['year'] = outage['year'].astype(int)
outage['state_abbr'] = outage['state_abbr'].str.strip().str.upper()
outage['outage_duration_hr'] = outage['outage_duration_min'] / 60
outage[['year','state','state_abbr','cause_category',
        'outage_duration_min','price_total']].head()

outage.to_csv('data/01-interim/outage_cleaned.csv', index = False)

# Aggregate to state × year for merging 
outage_agg = (
    outage
    .groupby(['year', 'state_abbr'])
    .agg(
        n_outages           = ('state_abbr',          'count'),
        total_duration_min  = ('outage_duration_min',  'sum'),
        mean_duration_min   = ('outage_duration_min',  'mean'),
        median_duration_min = ('outage_duration_min',  'median'),
        total_customers_aff = ('customers_affected',   'sum'),
        mean_demand_loss_mw = ('demand_loss_mw',       'mean'),
        mean_price_total    = ('price_total',          'mean'),
        mean_price_res      = ('price_residential',    'mean'),
        mean_price_com      = ('price_commercial',     'mean'),
        mean_price_ind      = ('price_industrial',     'mean'),
        mean_real_gsp       = ('real_gsp_usd',         'mean'),
    )
    .reset_index()
)

# Join state full name and climate region back for labeling
state_meta = (outage[['state_abbr','state','climate_region','nerc_region']]
              .drop_duplicates('state_abbr')
              .dropna(subset = ['state_abbr']))
outage_agg = outage_agg.merge(state_meta, on = 'state_abbr', how = 'left')

outage_agg.to_excel('data/02-processed/outage_state_year.xlsx', index = False)

# Merge the two processed datasets on state × year
caces_state_year  = pd.read_excel('data/02-processed/caces_state_year.xlsx')
outage_state_year = pd.read_excel('data/02-processed/outage_state_year.xlsx')

for df in [caces_state_year, outage_state_year]:
    df['state_abbr'] = df['state_abbr'].str.strip().str.upper()
    df['year'] = df['year'].astype(int)

merged = pd.merge(outage_state_year, caces_state_year,
                  on = ['year', 'state_abbr'], how = 'inner')
merged['log_mean_duration'] = np.log1p(merged['mean_duration_min'])
merged.to_csv('data/02-processed/merged_outage_air_quality.csv', index = False)

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# The EDA is organized into six sections that build from establishing data properties (pollutant trends, duration distribution) through associational analysis (correlations, regional heterogeneity) to mechanism testing (weather-caused vs. non-weather subsets).

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from matplotlib.patches import Patch
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from eda_utils import partial_r_year

merged = pd.read_csv('data/02-processed/merged_outage_air_quality.csv')
outage = pd.read_csv('data/01-interim/outage_cleaned.csv')
merged['log_mean_duration'] = np.log1p(merged['mean_duration_min'])
outage['weather_caused'] = (outage['cause_category'] == 'severe weather')

poll_cols = [c for c in merged.columns if c.startswith('poll_')]
poll_labels = {
    'poll_co':   'CO (ppm)',
    'poll_no2':  'NO\u2082 (ppb)',
    'poll_o3':   'O\u2083 (ppb)',
    'poll_pm10': 'PM10 (\u00b5g/m\u00b3)',
    'poll_pm25': 'PM2.5 (\u00b5g/m\u00b3)',
    'poll_so2':  'SO\u2082 (ppb)',
}

# %% [markdown]
# ### Section 1 — Air Pollutant Trends Over Time
#
# Before examining any relationship with outages, we establish whether pollutant concentrations trend over time. A shared downward trend in both pollutants and any outage metric would produce spurious correlations rather than a genuine association. We quantify each pollutant's trend with a linear regression on year.

# %%
# Figure 1: National average pollutant concentrations with OLS trend lines
national = merged.groupby('year')[poll_cols].mean().reset_index()
colors = sns.color_palette('tab10', len(poll_cols))

fig, axes = plt.subplots(2, 3, figsize = (14, 7), sharex = True)

for ax, poll, color in zip(axes.flat, poll_cols, colors):
    y = national[poll]
    ax.plot(national['year'], y, marker = 'o', lw = 2, color = color, markersize = 4)
    ax.fill_between(national['year'], y, alpha = 0.1, color = color)

    slope, intercept, r, p, _ = stats.linregress(national['year'], y)
    xs = np.array([national['year'].min(), national['year'].max()])
    ax.plot(xs, slope * xs + intercept, '--', color = 'gray', lw = 1.5)

    label = poll_labels.get(poll, poll)
    unit = label.split('(')[-1].replace(')', '') if '(' in label else ''
    ax.set_title(label.split(' ')[0])
    ax.set_ylabel(unit)
    ax.tick_params(axis = 'x', rotation = 40)
    ax.annotate(f'r\u00b2 = {r**2:.2f}, p = {p:.3f}',
                xy = (0.05, 0.08), xycoords = 'axes fraction',
                fontsize = 8, color = 'gray')

fig.suptitle('Figure 1: National Average Air Pollutant Concentrations, 2000\u20132016\n'
             '(dashed = OLS trend; r\u00b2 and p annotated per panel)', y = 1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# Every pollutant declined significantly over 2000–2016 (all p < 0.01), reflecting Clean Air Act enforcement, coal plant retirements, and vehicle emissions improvements. SO₂ and CO fell the most steeply in proportional terms; O₃ is the most volatile year-to-year because it is a secondary pollutant formed atmospherically rather than emitted directly.
#
# This shared downward trend is the central concern for our analysis. Any outage metric that also moves over time will appear correlated with pollutants for spurious reasons. We address this by computing partial correlations controlling for year in Section 3, and by including year as a covariate in all predictive models.

# %% [markdown]
# ### Section 2 — Outage Severity: Distribution and Cause Breakdown
#
# We examine the distribution of our primary outcome variable, outage duration, and break down events by cause category. Understanding the shape of the distribution and which causes dominate determines how we model severity and which subsets are most relevant to our research question.

# %%
# Figure 2: Outage duration distribution — raw vs. log-transformed
dur = outage['outage_duration_min'].dropna()

fig, axes = plt.subplots(1, 2, figsize = (12, 4))

axes[0].hist(dur.clip(upper = dur.quantile(0.99)), bins = 55,
             color = 'steelblue', edgecolor = 'white', lw = 0.4)
axes[0].set_xlabel('Duration (minutes)')
axes[0].set_ylabel('Number of Outages')
axes[0].set_title(f'Raw Duration (skewness = {dur.skew():.1f}; clipped at 99th pct.)')
axes[0].xaxis.set_major_formatter(
    mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

axes[1].hist(np.log1p(dur), bins = 50, color = 'tomato', edgecolor = 'white', lw = 0.4)
axes[1].set_xlabel('log(Duration + 1)')
axes[1].set_ylabel('Number of Outages')
axes[1].set_title(f'Log-Transformed Duration (skewness = {np.log1p(dur).skew():.2f})')

fig.suptitle('Figure 2: Power Outage Duration — Raw vs. Log-Transformed', y = 1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# Raw duration is severely right-skewed (skewness > 5), driven by a small number of catastrophic events — Hurricane Katrina (2005), Hurricane Ike (2008), and the 2011 derecho season. Log-transformation reduces skewness to near-symmetry and is used as the outcome variable throughout all subsequent analysis.

# %%
# Figure 3: Outage count and median duration by cause category
cause_stats = (
    outage.groupby('cause_category')
    .agg(n_outages = ('cause_category', 'count'),
         median_duration = ('outage_duration_min', 'median'))
    .sort_values('n_outages', ascending=True)
    .reset_index()
)

fig, axes = plt.subplots(1, 2, figsize = (13, 4))
axes[0].barh(cause_stats['cause_category'], cause_stats['n_outages'],
             color = 'steelblue', edgecolor = 'white')
axes[0].set_xlabel('Number of Outages')
axes[0].set_title('Outage Count by Cause')

axes[1].barh(cause_stats['cause_category'], cause_stats['median_duration'],
             color = 'darkorange', edgecolor = 'white')
axes[1].set_xlabel('Median Duration (minutes)')
axes[1].set_title('Median Duration by Cause')

fig.suptitle('Figure 3: Power Outage Characteristics by Cause Category', y = 1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# Severe weather accounts for nearly half of all outages and produces the longest median durations. This is the only cause category with a plausible atmospheric connection to air quality — the same stagnant high-pressure systems that trap pollution also cause heat waves that stress the grid. Intentional attacks are the second most frequent cause but produce shorter outages and have no plausible relationship to ambient pollution levels. For this reason we treat cause category as an important control, as any genuine pollutant signal should be stronger in the weather-caused subset.

# %% [markdown]
# ### Section 3 — Pollutant–Outage Associations
#
# We examine whether states and years with higher pollutant concentrations experience more severe outages, using two complementary approaches: a correlation heatmap comparing raw versus year-partialed correlations, and scatter plots of the strongest individual predictors.

# %%
# Figure 4: Raw vs. partial correlation heatmap
outcome_cols = ['mean_duration_min', 'median_duration_min',
                'n_outages', 'total_customers_aff']
outcome_labels = {
    'mean_duration_min':   'Mean Duration',
    'median_duration_min': 'Median Duration',
    'n_outages':           '# Outages',
    'total_customers_aff': 'Customers Affected',
}

raw_data, partial_data = [], []
for poll in poll_cols:
    raw_row, partial_row = {}, {}
    for out in outcome_cols:
        sub = merged[[poll, out, 'year']].dropna()
        raw_r = sub[[poll, out]].corr().iloc[0, 1]
        pr, _ = partial_r_year(sub, poll, out)
        raw_row[outcome_labels[out]]     = round(raw_r, 2)
        partial_row[outcome_labels[out]] = round(pr, 2)
    raw_data.append(raw_row)
    partial_data.append(partial_row)

raw_df     = pd.DataFrame(raw_data,
                           index = [p.replace('poll_', '').upper() for p in poll_cols])
partial_df = pd.DataFrame(partial_data, index = raw_df.index)

fig, axes = plt.subplots(1, 2, figsize = (14, 5))
for ax, df, title in zip(
        axes,
        [raw_df, partial_df],
        ['Raw Pearson r\n(includes shared time trend)',
         'Partial r (controlling for year)\n(removes time-trend confound)']):
    sns.heatmap(df, annot = True, fmt = '.2f', center = 0, vmin = -0.5, vmax = 0.5,
                cmap = 'coolwarm', linewidths = 0.4, ax = ax, annot_kws = {'size': 11})
    ax.set_title(title)
    ax.set_xlabel('Outage Metric')
    ax.set_ylabel('Pollutant')

fig.suptitle('Figure 4: Pollutant–Outage Correlations: Raw vs. Controlling for Year\n'
             '(positive = higher pollution \u2192 more severe outages)', y = 1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# The raw correlations (left) are consistently positive between pollutants and duration metrics (r = 0.10–0.25), but shrink after partialing out year (right). This confirms that part of the raw association reflects the shared downward time trend rather than a genuine relationship. However, most partial correlations remain positive and the pattern is consistent across all six pollutants, suggesting a real if modest association remains after controlling for time.
#
# The negative correlations with outage count likely reflect the time trend most strongly: outage counts peaked around 2011 while pollution had already been declining for a decade.

# %%
# Figure 5: Scatter plots of the two strongest pollutant predictors vs. log outage duration
corr_strength = (
    merged[poll_cols + ['mean_duration_min']]
    .corr()['mean_duration_min']
    .drop('mean_duration_min')
    .abs()
    .sort_values(ascending = False)
)
top_pols = corr_strength.index[:2]

fig, axes = plt.subplots(1, 2, figsize = (13, 5), sharey = True)
for ax, pol in zip(axes, top_pols):
    sns.scatterplot(data = merged, x = pol,
                    y = np.log1p(merged['mean_duration_min']),
                    hue = 'year', palette = 'viridis', alpha = 0.7, ax = ax)
    sns.regplot(data = merged, x = pol,
                y = np.log1p(merged['mean_duration_min']),
                scatter = False, color = 'black', line_kws = {'linewidth': 2}, ax = ax)
    ax.set_title(f'{pol.replace("poll_", "").upper()} vs Log Mean Outage Duration')
    ax.set_xlabel(f'{pol.replace("poll_", "").upper()} Concentration')
    ax.set_ylabel('log(Mean Duration + 1)')

fig.suptitle('Figure 5: Strongest Pollutant Predictors vs. Log Outage Duration', y = 1.03)
plt.tight_layout()
plt.show()

# %% [markdown]
# The pollutant concentration is positively correlated with power outage duration. The correlation does not appear to be very strong, as there is considerable variation above and below the regression line. The scatter plot also illustrates that both concentration and duration tend to be higher for earlier years, suggesting a potential time confound where both variables decrease as time progresses independently of one another.

# %% [markdown]
# ### Section 4 — Regional Heterogeneity
#
# The second part of our research question asks whether the pollutant–outage association varies by climate region. We use two approaches: within-region partial correlations and KNN classification accuracy by region.

# %%
# Figure 6: Within-region partial correlation heatmap
regions = merged['climate_region'].dropna().unique()
results = []

for poll in poll_cols:
    for region in regions:
        sub = merged[merged['climate_region'] == region][
            [poll, 'log_mean_duration', 'year']].dropna()
        if len(sub) >= 5:
            pr, pp = partial_r_year(sub, poll, 'log_mean_duration')
            results.append({
                'pollutant': poll.replace('poll_', '').upper(),
                'region': region,
                'partial_r': round(pr, 2),
                'p': round(pp, 3),
                'n': len(sub)
            })

corr_regional = pd.DataFrame(results)
corr_pivot = corr_regional.pivot(index = 'region', columns = 'pollutant',
                                  values = 'partial_r')

fig, ax = plt.subplots(figsize = (12, 6))
sns.heatmap(corr_pivot, annot = True, fmt = '.2f', center = 0,
            vmin = -0.6, vmax = 0.6,
            cmap = 'coolwarm', linewidths = 0.4, ax = ax, annot_kws = {'size': 10})
ax.set_title('Figure 6: Partial r (controlling for year): Pollutants vs. Log Outage Duration\n'
             'by Climate Region  —  positive = higher pollution \u2192 longer outages',
             pad = 12)
ax.set_xlabel('Pollutant')
ax.set_ylabel('Climate Region')
plt.tight_layout()
plt.show()

# %% [markdown]
# The within-region correlations vary substantially across climate zones, directly supporting the regional heterogeneity component of our hypothesis. Regions with consistent positive correlations across pollutants are ones where the atmospheric confounding mechanism is most plausible — high-pollution air masses and grid-stressing weather conditions co-occur there more reliably. Regions with near-zero or negative correlations suggest that local outage causes are driven by factors largely independent of ambient air quality.

# %%
# Figure 7: KNN classification accuracy by climate region
median_dur = merged['log_mean_duration'].median()
merged['high_severity'] = (merged['log_mean_duration'] > median_dur).astype(int)

feature_cols = poll_cols + ['year']
cv = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 39)

# Select best k on full dataset
clf_all = merged[feature_cols + ['high_severity']].dropna()
X_all = StandardScaler().fit_transform(clf_all[feature_cols])
y_all = clf_all['high_severity'].values

k_scores = [cross_val_score(KNeighborsClassifier(n_neighbors = k),
                             X_all, y_all, cv = cv, scoring = 'accuracy').mean()
            for k in range(1, 16)]
best_k = np.argmax(k_scores) + 1
overall_acc = max(k_scores)

# Per-region accuracy
region_accs = {}
clf_data = merged[feature_cols + ['high_severity', 'climate_region']].dropna()

for region in clf_data['climate_region'].unique():
    sub = clf_data[clf_data['climate_region'] == region]
    if len(sub) < 15:
        continue
    Xr  = StandardScaler().fit_transform(sub[feature_cols])
    yr  = sub['high_severity'].values
    k_r = min(best_k, len(sub) // 5)
    acc = cross_val_score(
        KNeighborsClassifier(n_neighbors = k_r), Xr, yr,
        cv = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 39),
        scoring = 'accuracy').mean()
    region_accs[region] = {'accuracy': acc, 'n': len(sub)}

region_acc_df = pd.DataFrame(region_accs).T.sort_values('accuracy', ascending=False)

fig, ax = plt.subplots(figsize = (11, 4))
bar_colors = ['tomato' if v > overall_acc else 'steelblue'
              for v in region_acc_df['accuracy']]
ax.bar(region_acc_df.index, region_acc_df['accuracy'],
       color = bar_colors, edgecolor = 'white')
ax.axhline(0.5, color = 'gray', ls = ':', lw = 1.5, label = 'Chance (0.50)')
ax.axhline(overall_acc, color = 'black', ls = '--', lw = 1.5,
           label = f'Overall CV accuracy ({overall_acc:.3f})')
ax.set_ylabel('5-Fold CV Accuracy')
ax.set_title('Figure 7: KNN Classification Accuracy by Climate Region\n'
             '(predicting above/below median outage duration from pollutant levels + year;\n'
             'red = above overall average, blue = below)', pad = 10)
ax.tick_params(axis = 'x', rotation = 40)
ax.legend(fontsize = 9)
plt.tight_layout()
plt.show()

# %% [markdown]
# KNN classification accuracy varies by region, confirming that pollutant levels are meaningfully more predictive of outage severity in some climate zones than others. This difference is detectable with a nonparametric classifier, not just correlation coefficients, providing convergent evidence for regional heterogeneity.

# %% [markdown]
# ### Section 5 — Weather-Caused vs. Non-Weather Outages
#
# Figure 3 established that severe weather dominates outage causes and produces the longest durations. The background section argues that the most plausible explanation for any pollutant–outage association is a shared atmospheric driver. If this mechanism is correct, the pollutant–duration association should be meaningfully stronger in state-years where weather-caused outages dominate.

# %%
# Figure 8: Partial r by cause subset — weather-dominated vs. non-weather state-years
weather_frac = (
    outage[outage['weather_caused']]
    .groupby(['year', 'state_abbr'])
    .size()
    .reset_index(name = 'n_weather')
)
total_out = (
    outage.groupby(['year', 'state_abbr'])
    .size()
    .reset_index(name = 'n_total')
)
weather_info = weather_frac.merge(total_out, on = ['year', 'state_abbr'])
weather_info['pct_weather'] = weather_info['n_weather'] / weather_info['n_total']

merged_w = merged.merge(
    weather_info[['year', 'state_abbr', 'pct_weather']],
    on = ['year', 'state_abbr'], how = 'left'
)
merged_w['pct_weather'] = merged_w['pct_weather'].fillna(0)

weather_sub     = merged_w[merged_w['pct_weather'] > 0.5].copy()
non_weather_sub = merged_w[merged_w['pct_weather'] <= 0.5].copy()

subsets = {
    'Weather-dominated\nstate-years':     weather_sub,
    'Non-weather-dominated\nstate-years': non_weather_sub,
}

fig, axes = plt.subplots(1, 2, figsize = (14, 5), sharey = True)

for ax, (label, sub_df) in zip(axes, subsets.items()):
    r_vals, p_vals, poll_names = [], [], []
    for poll in poll_cols:
        r, p = partial_r_year(sub_df, poll, 'log_mean_duration')
        r_vals.append(r)
        p_vals.append(p)
        poll_names.append(poll.replace('poll_', '').upper())

    bar_colors = ['tomato' if r > 0 else 'steelblue' for r in r_vals]
    bars = ax.bar(poll_names, r_vals, color=bar_colors, edgecolor='white')
    ax.axhline(0, color = 'gray', lw = 0.8)
    ax.set_ylim(-0.5, 0.5)
    ax.set_xlabel('Pollutant')
    ax.set_ylabel('Partial r (controlling for year)')
    ax.set_title(f'{label}\n(n = {len(sub_df)} state-years)')

    for bar, p in zip(bars, p_vals):
        sig = '***' if p < 0.001 else '**' if p < 0.01 else '*' if p < 0.05 else ''
        if sig:
            ax.text(bar.get_x() + bar.get_width() / 2,
                    bar.get_height() + 0.02, sig,
                    ha='center', fontsize = 11, color = 'black')

fig.suptitle('Figure 8: Partial Correlations — Weather-Dominated vs. Non-Weather State-Years\n'
             '(* p<0.05, ** p<0.01, *** p<0.001)', y = 1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# Partial correlations are consistently larger in magnitude in state-years where severe weather accounts for the majority of outages, and statistical significance is more frequently achieved in that subset. This supports the atmospheric confounding hypothesis: the same stagnant high-pressure systems that trap pollutants also cause the heat and wind conditions that stress grid infrastructure. The association is specifically amplified in the weather context where a shared atmospheric driver is most plausible.

# %% [markdown]
# ### Section 6 — Geographic Profile of Outage Severity and PM2.5

# %%
# Figure 9: State severity profile sorted by climate region, with PM2.5 overlay
state_profile = (
    merged.groupby(['state', 'climate_region'])
    .agg(
        mean_log_dur = ('log_mean_duration', 'mean'),
        mean_pm25    = ('poll_pm25',         'mean'),
        n_years      = ('year',              'count'),
    )
    .reset_index()
    .dropna(subset = ['mean_pm25', 'mean_log_dur', 'climate_region'])
)

region_order = (
    state_profile.groupby('climate_region')['mean_log_dur']
    .mean().sort_values(ascending = False).index
)
state_profile['region_rank'] = state_profile['climate_region'].map(
    {r: i for i, r in enumerate(region_order)})
state_profile = state_profile.sort_values(
    ['region_rank', 'mean_log_dur'], ascending = [True, False])

region_palette = dict(zip(region_order, sns.color_palette('tab10', len(region_order))))
bar_colors = state_profile['climate_region'].map(region_palette)

fig, ax1 = plt.subplots(figsize=(16, 5))
ax2 = ax1.twinx()
x = np.arange(len(state_profile))

ax1.bar(x, state_profile['mean_log_dur'],
        color = bar_colors, edgecolor = 'white', lw = 0.3, alpha = 0.85)
ax2.plot(x, state_profile['mean_pm25'], color='black',
         marker = 'o', markersize = 3, lw = 1.2, alpha = 0.6, label = 'Mean PM2.5')

ax1.set_xticks(x)
ax1.set_xticklabels(state_profile['state'], rotation = 75, ha = 'right', fontsize = 7.5)
ax1.set_ylabel('Mean log(Outage Duration + 1)')
ax2.set_ylabel('Mean PM2.5 (\u00b5g/m\u00b3)')
ax1.set_title(
    'Figure 9: Mean Log Outage Duration and PM2.5 by State\n'
    '(bars colored by climate region, sorted by region then duration;\n'
    'black line = PM2.5)', pad = 10)

legend_elements = [Patch(facecolor = region_palette[r], label = r) for r in region_order]
ax1.legend(handles = legend_elements, loc = 'upper right',
           fontsize = 7, ncol = 2, title = 'Climate Region')

plt.tight_layout()
plt.show()

# %% [markdown]
# Mean log outage duration is shown per state, grouped by climate region, alongside mean PM2.5 as a secondary axis. The PM2.5 line does not consistently mirror the duration bars within any single region, tempering the correlation findings from Figures 4 and 6. While statistical associations exist at the state-year level, they are not strong enough to produce a visually obvious geographic pattern — consistent with our hypothesis that the relationship is real but modest, and that pollution is a proxy for underlying atmospheric conditions rather than a direct predictor of outage severity.

# %% [markdown]
# ### EDA Summary
#
# Eight points establish the following findings that directly motivate the predictive modeling:
#
# 1. **All pollutants declined significantly 2000–2016** (Figure 1). This shared time trend is a confounder that must be controlled for — `year` is included as a covariate in all models.
#
# 2. **Outage duration is severely right-skewed** (Figure 2). Log-transformation brings skewness from >5 to near-zero and is used as the outcome variable throughout.
#
# 3. **Severe weather dominates outage causes** (Figure 3). It accounts for nearly half of all events and produces the longest durations. It is the only cause with a plausible atmospheric connection to air quality.
#
# 4. **Pollutants show weak positive associations with outage duration, partially explained by the time trend** (Figure 4 & 5). Raw correlations (r = 0.10–0.25) shrink but remain positive after partialing out year, indicating a genuine if modest signal beyond the time confound.
#
# 5. **The association varies substantially by climate region** (Figure 6). Some regions show consistent positive partial correlations across all six pollutants; others show near-zero or mixed-sign results, directly supporting the regional heterogeneity component of our hypothesis.
#
# 6. **KNN classification accuracy varies by region** (Figure 7), confirming that pollutant levels are meaningfully more predictive of outage severity in some climate zones than others.
#
# 7. **The pollutant–outage association is stronger in weather-dominated state-years** (Figure 8). This supports the atmospheric confounding hypothesis: the association is amplified precisely where a shared atmospheric driver is most plausible.
#
# 8. **Outage severity and PM2.5 do not track each other cleanly within regions** (Figure 9). This tempers the correlation findings — while statistical associations exist, they are not strong enough to produce a visually obvious geographic pattern.

# %% [markdown]
# ### Analysis 1 — Multiple OLS Regression
#
# The EDA established that pollutants have modest positive partial correlations with log outage duration after controlling for year. Regression formalizes this, where we fit a single model with all six pollutants and year as predictors, and examine which coefficients are statistically significant. We run the model twice - once on all state-years, and once restricted to weather-dominated state-years (>50% of outages caused by severe weather) - to test whether the signal is stronger in the subset where an atmospheric mechanism is most plausible.
#
# Predictors: poll_co, poll_no2, poll_o3, poll_pm10, poll_pm25, poll_so2, year
# Outcome: log(mean outage duration + 1)
# Method: OLS with standardized predictors so coefficients are comparable across pollutants

# %%
merged = pd.read_csv('data/02-processed/merged_outage_air_quality.csv')
outage = pd.read_csv('data/01-interim/outage_cleaned.csv')

merged['log_mean_duration'] = np.log1p(merged['mean_duration_min'])
outage['weather_caused'] = (outage['cause_category'] == 'severe weather')
 
poll_cols = [c for c in merged.columns if c.startswith('poll_')]
 
# Build the weather-fraction column needed for subsetting
weather_frac = (
    outage[outage['weather_caused']]
    .groupby(['year', 'state_abbr'])
    .size()
    .reset_index(name = 'n_weather')
)
total_out = (
    outage.groupby(['year', 'state_abbr'])
    .size()
    .reset_index(name = 'n_total')
)
weather_info = weather_frac.merge(total_out, on = ['year', 'state_abbr'])
weather_info['pct_weather'] = weather_info['n_weather'] / weather_info['n_total']
 
merged_w = merged.merge(
    weather_info[['year', 'state_abbr', 'pct_weather']],
    on = ['year', 'state_abbr'], how = 'left'
)
merged_w['pct_weather'] = merged_w['pct_weather'].fillna(0)
 
# Helper: run OLS and return a summary DataFrame 
def run_ols(df, feature_cols, outcome_col, label):
    """
    Fit OLS on standardized predictors.
    Returns a DataFrame of coefficients, standard errors, t-stats, and p-values,
    plus the model R².
    """
    sub   = df[feature_cols + [outcome_col]].dropna()
    X_raw = sub[feature_cols].values
    y     = sub[outcome_col].values
 
    # Standardize so coefficients are on the same scale (beta coefficients)
    scaler = StandardScaler()
    X = scaler.fit_transform(X_raw)
 
    # Fit with sklearn for predictions; compute stats manually
    model = LinearRegression().fit(X, y)
    y_hat = model.predict(X)
    r2    = r2_score(y, y_hat)
 
    n, p = X.shape
    residuals = y - y_hat
    sigma2    = residuals.var(ddof = p + 1)          # MSE
    XtX_inv   = np.linalg.pinv(X.T @ X)
    se        = np.sqrt(np.diag(XtX_inv) * sigma2)   # standard errors
    t_stats   = model.coef_ / se
    # Two-tailed p-values from t-distribution
    p_values  = [2 * (1 - stats.t.cdf(abs(t), df = n - p - 1)) for t in t_stats]
 
    results = pd.DataFrame({
        'predictor':  feature_cols,
        'beta_coef':  model.coef_.round(4),
        'std_error':  se.round(4),
        't_stat':     t_stats.round(3),
        'p_value':    [round(p, 4) for p in p_values],
        'significant': ['***' if p < 0.001 else '**' if p < 0.01
                        else '*' if p < 0.05 else '' for p in p_values]
    })
    print(f"\n{'='*55}")
    print(f"OLS Results — {label}  (n = {n}, R² = {r2:.3f})")
    print(f"{'='*55}")
    print(results.to_string(index = False))
    return results, r2
 
feature_cols = poll_cols + ['year']
 
results_all, r2_all = run_ols(
    merged_w, feature_cols, 'log_mean_duration', 'All state-years')
 
results_wx, r2_wx = run_ols(
    merged_w[merged_w['pct_weather'] > 0.5],
    feature_cols, 'log_mean_duration', 'Weather-dominated state-years')
# Out:
# ...
# OLS Results — All state-years  (n = 389, R² = 0.177)
# ...
# predictor  beta_coef  std_error  t_stat  p_value significant
#   poll_co    -0.1723     0.2010  -0.857   0.3920
#  poll_no2     0.2777     0.1556   1.785   0.0750
#   poll_o3    -0.3284     0.1203  -2.730   0.0066          **
# poll_pm10     0.2472     0.1219   2.028   0.0432           *
# poll_pm25     0.6059     0.1566   3.868   0.0001         ***
#  poll_so2    -0.2226     0.1809  -1.231   0.2192
#      year    -0.3780     0.1857  -2.036   0.0425           *
#
# ...
# OLS Results — Weather-dominated state-years  (n = 203, R² = 0.055)
# ...
# predictor  beta_coef  std_error  t_stat  p_value significant
#   poll_co     0.0585     0.2104   0.278   0.7812
#  poll_no2     0.1230     0.1682   0.731   0.4657
#   poll_o3     0.1188     0.1300   0.913   0.3622
# poll_pm10     0.1361     0.1173   1.160   0.2473
# poll_pm25    -0.1479     0.1828  -0.809   0.4196
#  poll_so2    -0.0751     0.1934  -0.388   0.6981
# ...

# %%
# Figure 10: coefficient plot comparing both models side by side
poll_labels_short = {
    'poll_co':   'CO',   'poll_no2': 'NO\u2082',
    'poll_o3':   'O\u2083',  'poll_pm10': 'PM10',
    'poll_pm25': 'PM2.5', 'poll_so2': 'SO\u2082',
    'year':      'Year'
}
 
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
datasets  = [
    (results_all, r2_all,  'All State-Years'),
    (results_wx,  r2_wx,   'Weather-Dominated State-Years'),
]
 
for ax, (res, r2, title) in zip(axes, datasets):
    poll_only = res[res['predictor'].isin(poll_cols)].copy()
    poll_only['label'] = poll_only['predictor'].map(poll_labels_short)
    colors = ['tomato' if b > 0 else 'steelblue' for b in poll_only['beta_coef']]
 
    bars = ax.barh(poll_only['label'], poll_only['beta_coef'],
                   color = colors, edgecolor = 'white')
    ax.axvline(0, color = 'gray', lw=0.8)
 
    # Add significance stars
    for bar, sig in zip(bars, poll_only['significant']):
        if sig:
            x = bar.get_width()
            offset = 0.002 if x >= 0 else -0.002
            ha = 'left' if x >= 0 else 'right'
            ax.text(x + offset, bar.get_y() + bar.get_height() / 2,
                    sig, va = 'center', ha = ha, fontsize = 11)
 
    ax.set_xlabel('Standardized Beta Coefficient')
    ax.set_title(f'{title}\n(R\u00b2 = {r2:.3f};  * p<0.05, ** p<0.01, *** p<0.001)')
 
axes[0].set_ylabel('Pollutant')
fig.suptitle(
    'Figure 10: OLS Regression — Standardized Pollutant Coefficients\n'
    'Predicting Log Mean Outage Duration (controlling for year)',
    y = 1.02
)
plt.tight_layout()
plt.show()

# %% [markdown]
# The OLS model on all state-years explains a moderate share of variance in log outage duration (R² = 0.177). After controlling for year, PM2.5 emerges as the strongest and most significant positive predictor (β = 0.606, p < 0.001), followed by PM10 (β = 0.247, p < 0.05). O₃ is the only pollutant with a significant *negative* coefficient (β = −0.328, p < 0.01), which is somewhat counterintuitive but consistent with O₃ being a secondary pollutant formed atmospherically, as its concentration reflects sunlight and temperature patterns rather than direct emissions and may behave differently from combustion-related pollutants in this context. CO, NO₂, and SO₂ do not reach significance after controlling for the other pollutants and year.
#
# The weather-dominated subset tells a different story (R² = 0.055). No individual pollutant reaches significance, and the PM2.5 coefficient actually flips negative (β = −0.148), reversing its direction from the full model. The overall model fit drops substantially. This is surprising given the EDA finding that pollutant–duration associations were stronger in weather-dominated state-years at the bivariate level. The regression result suggests that once all pollutants are included simultaneously and collinearity is accounted for, the signal in the weather subset is not robust. The smaller sample size (n = 203 vs. 389) also reduces statistical power, making it harder to detect effects that may genuinely exist.
#
# Taken together, the OLS results suggest that particulate matter — particularly PM2.5 — is the pollutant most consistently associated with outage severity in the full dataset, but that this association does not cleanly survive subsetting to weather-dominated state-years when all predictors are considered jointly.

# %% [markdown]
# ### Analysis 2 — Permutation Test: Are Pollutant–Outage Correlations Stronger Than Chance?
#
# The OLS regression shows which pollutants have significant coefficients, but significance depends on distributional assumptions (normality of residuals, etc.) that may not hold given the skewed outage data. A permutation test makes no such assumptions: it asks "how often would we see a correlation this large if the pairing between pollution levels and outage duration were random?"
#
# Procedure:
# 1. Compute the observed partial correlation (controlling for year) between each pollutant and log outage duration.
# 2. Randomly shuffle the pollutant column 5,000 times, recomputing the partial correlation each time to build a null distribution.
# 3. The empirical p-value is the fraction of permuted correlations that are as extreme as or more extreme than the observed value.
#
# We run this for all six pollutants and display the null distributions alongside the observed values. This validates (or challenges) the OLS significance results using a non-parametric approach.

# %%
n_perm = 5000
rng    = np.random.default_rng(39)
 
obs_r  = {}   # observed partial r per pollutant
null_r = {}   # null distribution per pollutant
emp_p  = {}   # empirical p-value per pollutant
 
analysis_df = merged[poll_cols + ['log_mean_duration', 'year']].dropna().copy()
 
for poll in poll_cols:
    sub = analysis_df[[poll, 'log_mean_duration', 'year']].dropna()
 
    # Observed partial r
    r_obs, _    = partial_r_year(sub, poll, 'log_mean_duration')
    obs_r[poll] = r_obs
 
    # Null distribution: shuffle the pollutant column, recompute partial r
    null_dist = []
    poll_vals = sub[poll].values.copy()
    for _ in range(n_perm):
        shuffled       = sub.copy()
        shuffled[poll] = rng.permutation(poll_vals)
        r_perm, _      = partial_r_year(shuffled, poll, 'log_mean_duration')
        null_dist.append(r_perm)
 
    null_r[poll] = np.array(null_dist)
 
    # Two-tailed empirical p-value
    emp_p[poll] = np.mean(np.abs(null_dist) >= abs(r_obs))
 
# Print summary table
print(f"\nPermutation Test Results (n_permutations={n_perm})\n{'='*50}")
print(f"{'Pollutant':<12} {'Observed r':>12} {'Emp. p-value':>14} {'Sig':>6}")
print('-' * 50)
for poll in poll_cols:
    name = poll.replace('poll_', '').upper()
    sig  = ('***' if emp_p[poll] < 0.001 else
            '**'  if emp_p[poll] < 0.01  else
            '*'   if emp_p[poll] < 0.05  else '')
    print(f"{name:<12} {obs_r[poll]:>12.4f} {emp_p[poll]:>14.4f} {sig:>6}")
# Out:
# Permutation Test Results (n_permutations=5000)
# ...
# Pollutant      Observed r   Emp. p-value    Sig
# --------------------------------------------------
# CO                -0.0653         0.2016
# NO2                0.0791         0.1204
# O3                -0.0393         0.4376
# PM10               0.1580         0.0024     **
# PM25               0.2606         0.0000    ***
# SO2                0.0788         0.1206

# %%
# Figure 11: null distributions with observed r marked
poll_labels_full = {
    'poll_co':   'CO',   'poll_no2': 'NO\u2082',
    'poll_o3':   'O\u2083',  'poll_pm10': 'PM10',
    'poll_pm25': 'PM2.5', 'poll_so2': 'SO\u2082',
}
 
fig, axes = plt.subplots(2, 3, figsize=(14, 7))
 
for ax, poll in zip(axes.flat, poll_cols):
    null = null_r[poll]
    r    = obs_r[poll]
    p    = emp_p[poll]
    name = poll_labels_full[poll]
 
    ax.hist(null, bins = 60, color = 'steelblue', edgecolor = 'white',
            lw = 0.3, alpha = 0.75, label = 'Null distribution')
    ax.axvline(r, color = 'tomato', lw = 2.5,
               label = f'Observed r = {r:.3f}')
    ax.axvline(-abs(r), color = 'tomato', lw = 2.5, ls = '--', alpha = 0.5)
 
    sig = ('***' if p < 0.001 else '**' if p < 0.01
           else '*' if p < 0.05 else 'n.s.')
    ax.set_title(f'{name}  (emp. p = {p:.3f}  {sig})')
    ax.set_xlabel('Permuted Partial r')
    ax.set_ylabel('Frequency')
    ax.legend(fontsize = 7)
 
fig.suptitle(
    f'Figure 11: Permutation Test Null Distributions vs. Observed Partial r\n'
    f'(controlling for year;  n = {n_perm:,} permutations;\n'
    f'dashed red = mirrored observed value for two-tailed reference)',
    y = 1.02
)
plt.tight_layout()
plt.show()

# %% [markdown]
# The permutation test provides non-parametric validation of the correlation results without assuming normally distributed residuals. Of the six pollutants, PM2.5 and PM10 are the only ones whose observed partial correlations fall reliably in the tail of the null distribution: PM2.5 shows an observed partial r of 0.261 (emp. p < 0.001) and PM10 shows r = 0.158 (emp. p = 0.002). Both are significant at the 0.01 level, confirming that their associations with outage duration are stronger than would be expected by random pairing of pollution levels and outage outcomes.
#
# CO, NO₂, O₃, and SO₂ do not reach significance under the permutation test (all emp. p > 0.12). Their observed partial r values fall well within the bulk of the null distribution, indicating that their apparent associations are consistent with chance variation after controlling for year.
#
# This partially aligns with the OLS results — both methods identify PM2.5 and PM10 as the strongest predictors — but the permutation test does not corroborate OLS's finding of a significant negative O₃ coefficient. That discrepancy likely reflects the difference between what each method is measuring: OLS estimates the conditional effect of O₃ holding all other pollutants constant (where multicollinearity among pollutants can inflate or distort individual coefficients), while the permutation test evaluates each pollutant's bivariate partial correlation with the outcome independently of the others. The fact that both PM2.5 and PM10 survive both tests strengthens confidence that their associations are real rather than artifacts of model specification.
#
# Overall, the permutation test converges on a consistent conclusion: among the six EPA criteria pollutants examined, particulate matter — specifically PM2.5 and PM10 — shows the most reliable statistical association with power outage severity, robust to both parametric and non-parametric testing approaches.

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
# - [X] **A.1 Informed consent**: Purdue and CACES report to practice informed consent or source from agencies that do.
# - [X] **A.2 Collection bias**: The Purdue dataset records only *major* outages, so smaller outages or those in less-populated areas may be underrepresented. The CACES data comes from EPA monitoring stations, which are unevenly distributed geographically. Merging at the state level masks finer within-state pollution-outage dynamics.
# - [X] **A.3 Limit PII exposure**: Personal data such as names and full addresses are not included. The most granular identifier is state, which is necessary for regional analysis.
# - [X] **A.4 Downstream bias mitigation**: The datasets do not include protected group status (race, income, etc.), limiting our ability to evaluate disparate impacts. This is an acknowledged gap.
#
# ### B. Data Storage
# - [X] **B.1 Data security**: Data is stored in a private GitHub repository, accessible only to project members.
# - [X] **B.2 Right to be forgotten**: Both datasets are aggregated public records with no individual-level identifiers; right-to-be-forgotten requests are not directly applicable.
# - [X] **B.3 Data retention plan**: The repository and its data can be deleted once the course concludes.
#
# ### C. Analysis
# - [X] **C.1 Missing perspectives**: State-level aggregation obscures impacts on less-populated or rural communities, who may face both greater pollution exposure and less reliable grids. A finer spatial resolution (e.g., county-level) would better capture these dynamics.
# - [X] **C.2 Dataset bias**: All pollutants declined monotonically over 2000–2016, likely due to broader policy shifts. Any correlation with outage patterns may partly reflect these parallel secular trends rather than a direct association. Year is included as a covariate in all models to mitigate this.
# - [X] **C.3 Honest representation**: We are careful to avoid implying that air pollutants *cause* power outages. The analysis establishes correlation; any causal interpretation would require an experimental or quasi-experimental design not available here.
# - [X] **C.4 Privacy in analysis**: No PII is used or displayed.
# - [X] **C.5 Auditability**: All data processing steps are reproducible from the code in this notebook; no stochastic steps are left unseeded.
#
# ### D. Modeling
# - [X] **D.1 Proxy discrimination**: Outage duration can serve as a proxy for grid investment and regional wealth, which may correlate with demographic characteristics. Analyzing by climate region rather than by socioeconomic indicators partially mitigates this.
# - [X] **D.2 Fairness across groups**: We have not formally tested for disparate error rates across demographic groups; this is a limitation of the available data.
# - [X] **D.3 Metric selection**: Optimizing on air pollutants alone may miss stronger predictors of outage severity (e.g., grid age, population density). We include multiple severity outcomes and both KNN and correlation-based approaches to triangulate findings.
# - [X] **D.4 Explainability**: Every modeling decision is documented in this notebook with written rationale.
# - [X] **D.5 Communicate limitations**: Key limitations — state-level aggregation, time-trend confounding, influence of extreme weather events, and the absence of true causal identification — are discussed throughout and in the conclusion.
#
# ### E. Deployment
# - [X] **E.1 Monitoring and evaluation**: Results will be manually reviewed by all team members before the final submission.
# - [X] **E.2 Redress**: This is an academic project; no production deployment is planned. If findings were extended to policy contexts, a formal bias audit would be required.
# - [X] **E.3 Roll back**: As an academic analysis, rollback consists of reverting to a prior git commit.
# - [X] **E.4 Unintended use**: The analysis establishes only correlation; any policy application claiming causation would constitute misuse of these findings.

# %% [markdown]
# ## Discussion and Conclusion
#
# This project investigated whether ambient air pollutant concentrations predict the severity of major power outages across the continental United States, and whether that association varies by climate region. Using a merged state × year dataset combining CACES air quality estimates and Purdue power outage records for 2000–2016, we found modest but consistent positive associations between pollutant levels and log-transformed outage duration, most clearly for PM2.5 and PM10. These associations survived partial correlation controls for year, though they were substantially attenuated compared to raw correlations, confirming that a shared downward time trend partially confounds the raw signal.
#
# Our background established a well-documented causal pathway running from outages to worsening air quality (via diesel generator use). This project tested the inverse: whether ambient pollution levels predict subsequent outage severity. The modest positive associations we found are consistent with the hypothesis that shared atmospheric drivers — particularly stagnant high-pressure systems that simultaneously trap pollutants and create heat stress on the grid — produce a detectable correlation even in the absence of a direct causal mechanism from pollution to infrastructure failure. The amplification of associations in weather-dominated state-years (Figure 8) is the strongest evidence for this atmospheric confounding interpretation.
#
# The within-region correlation heatmap (Figure 6) and KNN classification results (Figure 7) together demonstrate that the pollutant–outage association is not uniform across the U.S. This supports the regional component of our hypothesis and suggests that the atmospheric confounding mechanism operates more reliably in certain climate zones than others. Regions where pollution and severe weather stress tend to co-occur — particularly those with hot, humid summers — show the clearest signal.
#
# Several important limitations temper these findings. First, state-level aggregation masks within-state spatial variation in both pollution exposure and grid reliability; a county-level analysis might reveal sharper associations or important heterogeneity currently hidden by averaging. Second, the Purdue dataset records only *major* outages, potentially underrepresenting outage severity patterns in rural or less-populated areas. Third, while we control for year as a linear trend, other time-varying confounders (economic conditions, grid investment patterns) are not fully accounted for. Fourth, the analysis cannot establish causation: the shared atmospheric driver hypothesis is plausible but not identified from observational data alone.
#
# Future work could incorporate weather station data (temperature, humidity, wind) as explicit covariates to directly test the atmospheric confounding mechanism rather than relying on weather-cause categorization as a proxy. A county-level analysis joining CACES data to a more granular outage dataset would also substantially improve spatial precision. Longitudinal panel models with state fixed effects would better isolate within-state variation from cross-sectional confounding.
